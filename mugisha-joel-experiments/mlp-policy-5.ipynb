# %%
import subprocess
import sys

print("Installing dependencies for Kaggle environment...")

# Uninstall conflicting packages first
print("Removing conflicting packages...")
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "-q", "keras", "tensorflow"], 
               stderr=subprocess.DEVNULL)

# Install compatible versions
dependencies = [
    "numpy<2.0",
    "scipy<1.14",
    "protobuf<4.0",
    "tensorboard==2.15.0",
    "stable-baselines3[extra]==2.3.2",
    "ale-py==0.8.1",
    "gymnasium[atari,accept-rom-license]==0.29.1",
    "shimmy[atari]",
]

for dep in dependencies:
    print(f"Installing {dep}...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", dep])

print("\nAll dependencies installed successfully")
print("\nVerifying installation...")
try:
    import ale_py
    import gymnasium as gym
    from stable_baselines3 import DQN
    print("All imports successful!")
except Exception as e:
    print(f"Import error: {e}")
# Out:
# Installing dependencies for Kaggle environment...
# Removing conflicting packages...
# Installing numpy<2.0...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 80.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing scipy<1.14...
# Installing protobuf<4.0...
# Installing tensorboard==2.15.0...
# Installing stable-baselines3[extra]==2.3.2...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing ale-py==0.8.1...
# Installing gymnasium[atari,accept-rom-license]==0.29.1...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 13.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# kaggle-environments 1.18.0 requires gymnasium==0.29.0, but you have gymnasium 0.29.1 which is incompatible.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 0.2.1 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Installing shimmy[atari]...
#
# All dependencies installed successfully
#
# Verifying installation...
# All imports successful!

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import warnings
warnings.filterwarnings('ignore')

import ale_py
import gymnasium as gym
gym.register_envs(ale_py)
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np
import json
import torch
import gc

class LoggingCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(LoggingCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.current_reward = 0
        self.current_length = 0
        
    def _on_step(self):
        self.current_reward += self.locals['rewards'][0]
        self.current_length += 1
        
        if self.locals['dones'][0]:
            self.episode_rewards.append(self.current_reward)
            self.episode_lengths.append(self.current_length)
            self.current_reward = 0
            self.current_length = 0
            
            if len(self.episode_rewards) % 10 == 0:
                gc.collect()
                torch.cuda.empty_cache()
        return True

CONFIG = {
    "lr": 0.00005,
    "gamma": 0.97,
    "batch_size": 256,
    "eps_start": 0.8,
    "eps_end": 0.03,
    "eps_decay": 0.35,
    "policy": "MlpPolicy"
}

print(f"Training Configuration 5:")
print(f"Learning Rate: {CONFIG['lr']}")
print(f"Gamma: {CONFIG['gamma']}")
print(f"Batch Size: {CONFIG['batch_size']}")
print(f"Epsilon: {CONFIG['eps_start']} -> {CONFIG['eps_end']} (decay: {CONFIG['eps_decay']})")

gc.collect()
torch.cuda.empty_cache()

env = gym.make("ALE/SpaceInvaders-v5", frameskip=4)
env = DummyVecEnv([lambda: env])

model = DQN(
    CONFIG["policy"],
    env,
    learning_rate=CONFIG["lr"],
    gamma=CONFIG["gamma"],
    batch_size=CONFIG["batch_size"],
    buffer_size=20000,
    learning_starts=5000,
    exploration_initial_eps=CONFIG["eps_start"],
    exploration_final_eps=CONFIG["eps_end"],
    exploration_fraction=CONFIG["eps_decay"],
    target_update_interval=500,
    train_freq=4,
    gradient_steps=1,
    tensorboard_log="./logs/mlp-policy-5/",
    verbose=1,
    device="cuda" if torch.cuda.is_available() else "cpu"
)

callback = LoggingCallback()

model.learn(
    total_timesteps=300000,
    tb_log_name="SpaceInvaders_MlpPolicy_5",
    callback=callback,
    progress_bar=True
)

mean_reward, std_reward = evaluate_policy(
    model,
    env,
    n_eval_episodes=10,
    deterministic=True
)

results = {
    "config": CONFIG,
    "mean_reward": float(mean_reward),
    "std_reward": float(std_reward),
    "episode_rewards": [float(r) for r in callback.episode_rewards],
    "episode_lengths": [int(l) for l in callback.episode_lengths],
    "total_episodes": len(callback.episode_rewards)
}

model.save("/kaggle/working/train-mlp-policy-5")

with open("/kaggle/working/train-mlp-policy-5-results.json", "w") as f:
    json.dump(results, f, indent=2)

print(f"\nTraining Complete")
print(f"Mean Reward: {mean_reward:.2f} +/- {std_reward:.2f}")
print(f"Total Episodes: {len(callback.episode_rewards)}")
print(f"Model saved to: /kaggle/working/train-mlp-policy-5.zip")
print(f"Results saved to: /kaggle/working/train-mlp-policy-5-results.json")

env.close()
gc.collect()
torch.cuda.empty_cache()
# Out:
# Training Configuration 5:
# Learning Rate: 5e-05
# Gamma: 0.97
# Batch Size: 256
# Epsilon: 0.8 -> 0.03 (decay: 0.35)
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/mlp-policy-5/SpaceInvaders_MlpPolicy_5_1
# Output()
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1003     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2036     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1005     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4019     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.755    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 411      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 6076     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.209    |
# |    n_updates        | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 257      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 7945     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.415    |
# |    n_updates        | 736      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.722    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 195      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 10686    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.115    |
# |    n_updates        | 1421     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.707    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 176      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 12718    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.209    |
# |    n_updates        | 1929     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.687    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 161      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 15434    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.249    |
# |    n_updates        | 2608     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.677    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 156      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 16788    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.236    |
# |    n_updates        | 2946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.661    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 150      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 18989    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0208   |
# |    n_updates        | 3497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.648    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 146      |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 20670    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.276    |
# |    n_updates        | 3917     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.636    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 144      |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 22315    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.337    |
# |    n_updates        | 4328     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.621    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 141      |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 24455    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.455    |
# |    n_updates        | 4863     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.604    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 138      |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 26676    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.11     |
# |    n_updates        | 5418     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.588    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 136      |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 28932    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.176    |
# |    n_updates        | 5982     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.573    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 134      |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 30902    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.175    |
# |    n_updates        | 6475     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 133      |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 33368    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.278    |
# |    n_updates        | 7091     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.543    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 132      |
# |    time_elapsed     | 264      |
# |    total_timesteps  | 35011    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.488    |
# |    n_updates        | 7502     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 131      |
# |    time_elapsed     | 284      |
# |    total_timesteps  | 37310    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.197    |
# |    n_updates        | 8077     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.511    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 130      |
# |    time_elapsed     | 302      |
# |    total_timesteps  | 39386    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.213    |
# |    n_updates        | 8596     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.496    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 129      |
# |    time_elapsed     | 321      |
# |    total_timesteps  | 41515    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.18     |
# |    n_updates        | 9128     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.479    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 128      |
# |    time_elapsed     | 340      |
# |    total_timesteps  | 43714    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.209    |
# |    n_updates        | 9678     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.462    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 127      |
# |    time_elapsed     | 361      |
# |    total_timesteps  | 46114    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.448    |
# |    n_updates        | 10278    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.453    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 127      |
# |    time_elapsed     | 371      |
# |    total_timesteps  | 47274    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.512    |
# |    n_updates        | 10568    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.442    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 126      |
# |    time_elapsed     | 384      |
# |    total_timesteps  | 48812    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.336    |
# |    n_updates        | 10952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.424    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 126      |
# |    time_elapsed     | 407      |
# |    total_timesteps  | 51332    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0873   |
# |    n_updates        | 11582    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.407    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 125      |
# |    time_elapsed     | 426      |
# |    total_timesteps  | 53536    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.212    |
# |    n_updates        | 12133    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.39     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 124      |
# |    time_elapsed     | 446      |
# |    total_timesteps  | 55844    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.222    |
# |    n_updates        | 12710    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.374    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 124      |
# |    time_elapsed     | 466      |
# |    total_timesteps  | 58038    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.11     |
# |    n_updates        | 13259    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.358    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 123      |
# |    time_elapsed     | 485      |
# |    total_timesteps  | 60233    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.371    |
# |    n_updates        | 13808    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.34     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 123      |
# |    time_elapsed     | 508      |
# |    total_timesteps  | 62780    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.199    |
# |    n_updates        | 14444    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.322    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 123      |
# |    time_elapsed     | 530      |
# |    total_timesteps  | 65200    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.123    |
# |    n_updates        | 15049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.308    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 122      |
# |    time_elapsed     | 546      |
# |    total_timesteps  | 67093    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.352    |
# |    n_updates        | 15523    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.291    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 122      |
# |    time_elapsed     | 567      |
# |    total_timesteps  | 69342    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.204    |
# |    n_updates        | 16085    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.276    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 121      |
# |    time_elapsed     | 586      |
# |    total_timesteps  | 71485    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.218    |
# |    n_updates        | 16621    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.256    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 121      |
# |    time_elapsed     | 610      |
# |    total_timesteps  | 74137    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.346    |
# |    n_updates        | 17284    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.24     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 121      |
# |    time_elapsed     | 629      |
# |    total_timesteps  | 76325    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.337    |
# |    n_updates        | 17831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.227    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 120      |
# |    time_elapsed     | 646      |
# |    total_timesteps  | 78171    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.341    |
# |    n_updates        | 18292    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.209    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 120      |
# |    time_elapsed     | 668      |
# |    total_timesteps  | 80659    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.246    |
# |    n_updates        | 18914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.188    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 120      |
# |    time_elapsed     | 694      |
# |    total_timesteps  | 83522    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.28     |
# |    n_updates        | 19630    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.174    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 120      |
# |    time_elapsed     | 710      |
# |    total_timesteps  | 85334    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.356    |
# |    n_updates        | 20083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.16     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 119      |
# |    time_elapsed     | 728      |
# |    total_timesteps  | 87323    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.375    |
# |    n_updates        | 20580    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.144    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 119      |
# |    time_elapsed     | 748      |
# |    total_timesteps  | 89448    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.149    |
# |    n_updates        | 21111    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.122    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 119      |
# |    time_elapsed     | 775      |
# |    total_timesteps  | 92459    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.101    |
# |    n_updates        | 21864    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.101    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 118      |
# |    time_elapsed     | 801      |
# |    total_timesteps  | 95315    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.163    |
# |    n_updates        | 22578    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.08     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 118      |
# |    time_elapsed     | 828      |
# |    total_timesteps  | 98184    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.242    |
# |    n_updates        | 23295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0615   |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 118      |
# |    time_elapsed     | 851      |
# |    total_timesteps  | 100709   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.404    |
# |    n_updates        | 23927    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0451   |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 118      |
# |    time_elapsed     | 871      |
# |    total_timesteps  | 102938   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.23     |
# |    n_updates        | 24484    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 117      |
# |    time_elapsed     | 900      |
# |    total_timesteps  | 106082   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.206    |
# |    n_updates        | 25270    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 117      |
# |    time_elapsed     | 927      |
# |    total_timesteps  | 108971   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.381    |
# |    n_updates        | 25992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 117      |
# |    time_elapsed     | 950      |
# |    total_timesteps  | 111463   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.421    |
# |    n_updates        | 26615    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 117      |
# |    time_elapsed     | 967      |
# |    total_timesteps  | 113334   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.193    |
# |    n_updates        | 27083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 116      |
# |    time_elapsed     | 991      |
# |    total_timesteps  | 115939   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.35     |
# |    n_updates        | 27734    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 116      |
# |    time_elapsed     | 1015     |
# |    total_timesteps  | 118559   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.189    |
# |    n_updates        | 28389    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 116      |
# |    time_elapsed     | 1035     |
# |    total_timesteps  | 120786   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.427    |
# |    n_updates        | 28946    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 116      |
# |    time_elapsed     | 1056     |
# |    total_timesteps  | 123041   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.371    |
# |    n_updates        | 29510    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 116      |
# |    time_elapsed     | 1079     |
# |    total_timesteps  | 125510   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.221    |
# |    n_updates        | 30127    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 116      |
# |    time_elapsed     | 1103     |
# |    total_timesteps  | 128184   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.27     |
# |    n_updates        | 30795    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 116      |
# |    time_elapsed     | 1118     |
# |    total_timesteps  | 129720   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.358    |
# |    n_updates        | 31179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 115      |
# |    time_elapsed     | 1144     |
# |    total_timesteps  | 132553   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0411   |
# |    n_updates        | 31888    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 115      |
# |    time_elapsed     | 1164     |
# |    total_timesteps  | 134705   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.393    |
# |    n_updates        | 32426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 115      |
# |    time_elapsed     | 1188     |
# |    total_timesteps  | 137363   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.386    |
# |    n_updates        | 33090    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 115      |
# |    time_elapsed     | 1209     |
# |    total_timesteps  | 139653   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.197    |
# |    n_updates        | 33663    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 115      |
# |    time_elapsed     | 1226     |
# |    total_timesteps  | 141471   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.361    |
# |    n_updates        | 34117    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 115      |
# |    time_elapsed     | 1248     |
# |    total_timesteps  | 143895   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.578    |
# |    n_updates        | 34723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 115      |
# |    time_elapsed     | 1269     |
# |    total_timesteps  | 146076   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.87     |
# |    n_updates        | 35268    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 114      |
# |    time_elapsed     | 1290     |
# |    total_timesteps  | 148436   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.833    |
# |    n_updates        | 35858    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 114      |
# |    time_elapsed     | 1313     |
# |    total_timesteps  | 150885   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.164    |
# |    n_updates        | 36471    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 114      |
# |    time_elapsed     | 1335     |
# |    total_timesteps  | 153223   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.269    |
# |    n_updates        | 37055    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 114      |
# |    time_elapsed     | 1357     |
# |    total_timesteps  | 155597   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.234    |
# |    n_updates        | 37649    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 114      |
# |    time_elapsed     | 1373     |
# |    total_timesteps  | 157305   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.324    |
# |    n_updates        | 38076    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 114      |
# |    time_elapsed     | 1389     |
# |    total_timesteps  | 159097   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.348    |
# |    n_updates        | 38524    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 114      |
# |    time_elapsed     | 1402     |
# |    total_timesteps  | 160436   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.402    |
# |    n_updates        | 38858    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 114      |
# |    time_elapsed     | 1416     |
# |    total_timesteps  | 161966   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.371    |
# |    n_updates        | 39241    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 114      |
# |    time_elapsed     | 1437     |
# |    total_timesteps  | 164230   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.199    |
# |    n_updates        | 39807    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 114      |
# |    time_elapsed     | 1456     |
# |    total_timesteps  | 166319   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.491    |
# |    n_updates        | 40329    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 114      |
# |    time_elapsed     | 1474     |
# |    total_timesteps  | 168240   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.194    |
# |    n_updates        | 40809    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 113      |
# |    time_elapsed     | 1493     |
# |    total_timesteps  | 170241   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.257    |
# |    n_updates        | 41310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 113      |
# |    time_elapsed     | 1518     |
# |    total_timesteps  | 172876   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.398    |
# |    n_updates        | 41968    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 113      |
# |    time_elapsed     | 1542     |
# |    total_timesteps  | 175484   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.12     |
# |    n_updates        | 42620    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 113      |
# |    time_elapsed     | 1565     |
# |    total_timesteps  | 177924   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.376    |
# |    n_updates        | 43230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 113      |
# |    time_elapsed     | 1586     |
# |    total_timesteps  | 180202   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.488    |
# |    n_updates        | 43800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 113      |
# |    time_elapsed     | 1604     |
# |    total_timesteps  | 182207   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.553    |
# |    n_updates        | 44301    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 113      |
# |    time_elapsed     | 1625     |
# |    total_timesteps  | 184457   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.259    |
# |    n_updates        | 44864    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 113      |
# |    time_elapsed     | 1648     |
# |    total_timesteps  | 186871   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.528    |
# |    n_updates        | 45467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 113      |
# |    time_elapsed     | 1667     |
# |    total_timesteps  | 188967   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.287    |
# |    n_updates        | 45991    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 113      |
# |    time_elapsed     | 1690     |
# |    total_timesteps  | 191393   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.226    |
# |    n_updates        | 46598    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 113      |
# |    time_elapsed     | 1711     |
# |    total_timesteps  | 193651   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.337    |
# |    n_updates        | 47162    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 113      |
# |    time_elapsed     | 1731     |
# |    total_timesteps  | 195891   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.261    |
# |    n_updates        | 47722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 113      |
# |    time_elapsed     | 1755     |
# |    total_timesteps  | 198435   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.145    |
# |    n_updates        | 48358    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 112      |
# |    time_elapsed     | 1776     |
# |    total_timesteps  | 200654   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.344    |
# |    n_updates        | 48913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 112      |
# |    time_elapsed     | 1802     |
# |    total_timesteps  | 203495   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0893   |
# |    n_updates        | 49623    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 112      |
# |    time_elapsed     | 1822     |
# |    total_timesteps  | 205658   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.18     |
# |    n_updates        | 50164    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 112      |
# |    time_elapsed     | 1851     |
# |    total_timesteps  | 208752   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.164    |
# |    n_updates        | 50937    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 112      |
# |    time_elapsed     | 1871     |
# |    total_timesteps  | 210904   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.35     |
# |    n_updates        | 51475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 112      |
# |    time_elapsed     | 1889     |
# |    total_timesteps  | 212813   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.219    |
# |    n_updates        | 51953    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 112      |
# |    time_elapsed     | 1915     |
# |    total_timesteps  | 215740   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.466    |
# |    n_updates        | 52684    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 112      |
# |    time_elapsed     | 1940     |
# |    total_timesteps  | 218354   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.104    |
# |    n_updates        | 53338    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 112      |
# |    time_elapsed     | 1963     |
# |    total_timesteps  | 220883   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.392    |
# |    n_updates        | 53970    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 112      |
# |    time_elapsed     | 2001     |
# |    total_timesteps  | 224938   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.387    |
# |    n_updates        | 54984    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 112      |
# |    time_elapsed     | 2023     |
# |    total_timesteps  | 227292   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.472    |
# |    n_updates        | 55572    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 112      |
# |    time_elapsed     | 2042     |
# |    total_timesteps  | 229376   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.693    |
# |    n_updates        | 56093    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 112      |
# |    time_elapsed     | 2065     |
# |    total_timesteps  | 231874   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.479    |
# |    n_updates        | 56718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 112      |
# |    time_elapsed     | 2100     |
# |    total_timesteps  | 235591   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.63     |
# |    n_updates        | 57647    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 112      |
# |    time_elapsed     | 2118     |
# |    total_timesteps  | 237545   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.823    |
# |    n_updates        | 58136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 112      |
# |    time_elapsed     | 2146     |
# |    total_timesteps  | 240610   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.36     |
# |    n_updates        | 58902    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 112      |
# |    time_elapsed     | 2168     |
# |    total_timesteps  | 242970   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.312    |
# |    n_updates        | 59492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 112      |
# |    time_elapsed     | 2186     |
# |    total_timesteps  | 244988   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.433    |
# |    n_updates        | 59996    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 111      |
# |    time_elapsed     | 2202     |
# |    total_timesteps  | 246712   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.527    |
# |    n_updates        | 60427    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 111      |
# |    time_elapsed     | 2223     |
# |    total_timesteps  | 248919   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.39     |
# |    n_updates        | 60979    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 111      |
# |    time_elapsed     | 2244     |
# |    total_timesteps  | 251222   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.383    |
# |    n_updates        | 61555    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 111      |
# |    time_elapsed     | 2267     |
# |    total_timesteps  | 253780   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.462    |
# |    n_updates        | 62194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 111      |
# |    time_elapsed     | 2291     |
# |    total_timesteps  | 256307   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.715    |
# |    n_updates        | 62826    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 111      |
# |    time_elapsed     | 2317     |
# |    total_timesteps  | 259148   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.188    |
# |    n_updates        | 63536    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 111      |
# |    time_elapsed     | 2341     |
# |    total_timesteps  | 261793   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.485    |
# |    n_updates        | 64198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 111      |
# |    time_elapsed     | 2368     |
# |    total_timesteps  | 264709   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.562    |
# |    n_updates        | 64927    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 111      |
# |    time_elapsed     | 2401     |
# |    total_timesteps  | 268308   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.389    |
# |    n_updates        | 65826    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 111      |
# |    time_elapsed     | 2423     |
# |    total_timesteps  | 270691   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.458    |
# |    n_updates        | 66422    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 111      |
# |    time_elapsed     | 2445     |
# |    total_timesteps  | 273061   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.306    |
# |    n_updates        | 67015    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 111      |
# |    time_elapsed     | 2474     |
# |    total_timesteps  | 276317   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.556    |
# |    n_updates        | 67829    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 111      |
# |    time_elapsed     | 2500     |
# |    total_timesteps  | 279082   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.652    |
# |    n_updates        | 68520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 111      |
# |    time_elapsed     | 2527     |
# |    total_timesteps  | 282044   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.517    |
# |    n_updates        | 69260    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 111      |
# |    time_elapsed     | 2544     |
# |    total_timesteps  | 283894   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.245    |
# |    n_updates        | 69723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 111      |
# |    time_elapsed     | 2573     |
# |    total_timesteps  | 287092   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.503    |
# |    n_updates        | 70522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 111      |
# |    time_elapsed     | 2596     |
# |    total_timesteps  | 289506   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.364    |
# |    n_updates        | 71126    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 111      |
# |    time_elapsed     | 2620     |
# |    total_timesteps  | 292107   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.495    |
# |    n_updates        | 71776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 111      |
# |    time_elapsed     | 2634     |
# |    total_timesteps  | 293653   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.798    |
# |    n_updates        | 72163    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 111      |
# |    time_elapsed     | 2659     |
# |    total_timesteps  | 296404   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.517    |
# |    n_updates        | 72850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.03     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 111      |
# |    time_elapsed     | 2682     |
# |    total_timesteps  | 298805   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.355    |
# |    n_updates        | 73451    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training Complete
# Mean Reward: 294.00 +/- 109.54
# Total Episodes: 513
# Model saved to: /kaggle/working/train-mlp-policy-5.zip
# Results saved to: /kaggle/working/train-mlp-policy-5-results.json

# %%
from IPython.display import FileLink
FileLink('train-mlp-policy-4.zip')
# Out:
# /kaggle/working/train-mlp-policy-4.zip
