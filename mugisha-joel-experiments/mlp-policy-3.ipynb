# %%
import subprocess
import sys

print("Installing dependencies for Kaggle environment...")

# Uninstall conflicting packages first
print("Removing conflicting packages...")
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "-q", "keras", "tensorflow"], 
               stderr=subprocess.DEVNULL)

# Install compatible versions
dependencies = [
    "numpy<2.0",
    "scipy<1.14",
    "protobuf<4.0",
    "tensorboard==2.15.0",
    "stable-baselines3[extra]==2.3.2",
    "ale-py==0.8.1",
    "gymnasium[atari,accept-rom-license]==0.29.1",
    "shimmy[atari]",
]

for dep in dependencies:
    print(f"Installing {dep}...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", dep])

print("\nAll dependencies installed successfully")
print("\nVerifying installation...")
try:
    import ale_py
    import gymnasium as gym
    from stable_baselines3 import DQN
    print("All imports successful!")
except Exception as e:
    print(f"Import error: {e}")
# Out:
# Installing dependencies for Kaggle environment...
# Removing conflicting packages...
# Installing numpy<2.0...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 80.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing scipy<1.14...
# Installing protobuf<4.0...
# Installing tensorboard==2.15.0...
# Installing stable-baselines3[extra]==2.3.2...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing ale-py==0.8.1...
# Installing gymnasium[atari,accept-rom-license]==0.29.1...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 13.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# kaggle-environments 1.18.0 requires gymnasium==0.29.0, but you have gymnasium 0.29.1 which is incompatible.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 0.2.1 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Installing shimmy[atari]...
#
# All dependencies installed successfully
#
# Verifying installation...
# All imports successful!

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import warnings
warnings.filterwarnings('ignore')

import ale_py
import gymnasium as gym
gym.register_envs(ale_py)
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np
import json
import torch
import gc

class LoggingCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(LoggingCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.current_reward = 0
        self.current_length = 0
        
    def _on_step(self):
        self.current_reward += self.locals['rewards'][0]
        self.current_length += 1
        
        if self.locals['dones'][0]:
            self.episode_rewards.append(self.current_reward)
            self.episode_lengths.append(self.current_length)
            self.current_reward = 0
            self.current_length = 0
            
            if len(self.episode_rewards) % 10 == 0:
                gc.collect()
                torch.cuda.empty_cache()
        return True

CONFIG = {
    "lr": 0.00025,
    "gamma": 0.99,
    "batch_size": 128,
    "eps_start": 0.9,
    "eps_end": 0.02,
    "eps_decay": 0.25,
    "policy": "MlpPolicy"
}

print(f"Training Configuration 3:")
print(f"Learning Rate: {CONFIG['lr']}")
print(f"Gamma: {CONFIG['gamma']}")
print(f"Batch Size: {CONFIG['batch_size']}")
print(f"Epsilon: {CONFIG['eps_start']} -> {CONFIG['eps_end']} (decay: {CONFIG['eps_decay']})")

gc.collect()
torch.cuda.empty_cache()

env = gym.make("ALE/SpaceInvaders-v5", frameskip=4)
env = DummyVecEnv([lambda: env])

model = DQN(
    CONFIG["policy"],
    env,
    learning_rate=CONFIG["lr"],
    gamma=CONFIG["gamma"],
    batch_size=CONFIG["batch_size"],
    buffer_size=20000,
    learning_starts=5000,
    exploration_initial_eps=CONFIG["eps_start"],
    exploration_final_eps=CONFIG["eps_end"],
    exploration_fraction=CONFIG["eps_decay"],
    target_update_interval=500,
    train_freq=4,
    gradient_steps=1,
    tensorboard_log="./logs/mlp-policy-3/",
    verbose=1,
    device="cuda" if torch.cuda.is_available() else "cpu"
)

callback = LoggingCallback()

model.learn(
    total_timesteps=300000,
    tb_log_name="SpaceInvaders_MlpPolicy_3",
    callback=callback,
    progress_bar=True
)

mean_reward, std_reward = evaluate_policy(
    model,
    env,
    n_eval_episodes=10,
    deterministic=True
)

results = {
    "config": CONFIG,
    "mean_reward": float(mean_reward),
    "std_reward": float(std_reward),
    "episode_rewards": [float(r) for r in callback.episode_rewards],
    "episode_lengths": [int(l) for l in callback.episode_lengths],
    "total_episodes": len(callback.episode_rewards)
}

model.save("/kaggle/working/train-mlp-policy-3")

with open("/kaggle/working/train-mlp-policy-3-results.json", "w") as f:
    json.dump(results, f, indent=2)

print(f"\nTraining Complete")
print(f"Mean Reward: {mean_reward:.2f} +/- {std_reward:.2f}")
print(f"Total Episodes: {len(callback.episode_rewards)}")
print(f"Model saved to: /kaggle/working/train-mlp-policy-3.zip")
print(f"Results saved to: /kaggle/working/train-mlp-policy-3-results.json")

env.close()
gc.collect()
torch.cuda.empty_cache()
# Out:
# Training Configuration 3:
# Learning Rate: 0.00025
# Gamma: 0.99
# Batch Size: 128
# Epsilon: 0.9 -> 0.02 (decay: 0.25)
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/mlp-policy-3/SpaceInvaders_MlpPolicy_3_1
# Output()
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 973      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1956     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 982      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4261     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 547      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 6101     |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.456    |
# |    n_updates        | 275      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 396      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 7852     |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0718   |
# |    n_updates        | 712      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 332      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 9786     |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.384    |
# |    n_updates        | 1196     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 306      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 11292    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.75     |
# |    n_updates        | 1572     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 283      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 13359    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0175   |
# |    n_updates        | 2089     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.717    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 266      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 15569    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.18     |
# |    n_updates        | 2642     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 257      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 17410    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.121    |
# |    n_updates        | 3102     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.678    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 250      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 18884    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.19     |
# |    n_updates        | 3470     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.657    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 244      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 20733    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.84     |
# |    n_updates        | 3933     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 239      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 22877    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.199    |
# |    n_updates        | 4469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.6      |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 234      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 25573    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0989   |
# |    n_updates        | 5143     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.577    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 231      |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 27539    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.524    |
# |    n_updates        | 5634     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.545    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 227      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 30265    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.651    |
# |    n_updates        | 6316     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.523    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 225      |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 32108    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.434    |
# |    n_updates        | 6776     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.496    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 223      |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 34415    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.414    |
# |    n_updates        | 7353     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.477    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 221      |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 36090    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.305    |
# |    n_updates        | 7772     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.452    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 219      |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 38145    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.209    |
# |    n_updates        | 8286     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.429    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 217      |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 40184    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.686    |
# |    n_updates        | 8795     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.407    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 216      |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 41982    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.315    |
# |    n_updates        | 9245     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.382    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 215      |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 44186    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.593    |
# |    n_updates        | 9796     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.354    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 213      |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 46574    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.837    |
# |    n_updates        | 10393    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.322    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 212      |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 49221    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.848    |
# |    n_updates        | 11055    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.296    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 210      |
# |    time_elapsed     | 244      |
# |    total_timesteps  | 51519    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.588    |
# |    n_updates        | 11629    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.266    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 209      |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 54037    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.743    |
# |    n_updates        | 12259    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.238    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 208      |
# |    time_elapsed     | 271      |
# |    total_timesteps  | 56403    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.78     |
# |    n_updates        | 12850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.21     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 206      |
# |    time_elapsed     | 284      |
# |    total_timesteps  | 58826    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.9      |
# |    n_updates        | 13456    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.179    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 205      |
# |    time_elapsed     | 298      |
# |    total_timesteps  | 61421    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.304    |
# |    n_updates        | 14105    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.157    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 204      |
# |    time_elapsed     | 309      |
# |    total_timesteps  | 63283    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.322    |
# |    n_updates        | 14570    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.141    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 204      |
# |    time_elapsed     | 316      |
# |    total_timesteps  | 64704    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.762    |
# |    n_updates        | 14925    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.107    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 203      |
# |    time_elapsed     | 332      |
# |    total_timesteps  | 67544    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.55     |
# |    n_updates        | 15635    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0791   |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 201      |
# |    time_elapsed     | 346      |
# |    total_timesteps  | 69963    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.398    |
# |    n_updates        | 16240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0504   |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 200      |
# |    time_elapsed     | 360      |
# |    total_timesteps  | 72413    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.408    |
# |    n_updates        | 16853    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0285   |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 199      |
# |    time_elapsed     | 371      |
# |    total_timesteps  | 74277    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.326    |
# |    n_updates        | 17319    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 198      |
# |    time_elapsed     | 384      |
# |    total_timesteps  | 76558    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.695    |
# |    n_updates        | 17889    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 198      |
# |    time_elapsed     | 397      |
# |    total_timesteps  | 78736    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.897    |
# |    n_updates        | 18433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 197      |
# |    time_elapsed     | 411      |
# |    total_timesteps  | 81080    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.831    |
# |    n_updates        | 19019    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 196      |
# |    time_elapsed     | 422      |
# |    total_timesteps  | 83130    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.518    |
# |    n_updates        | 19532    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 195      |
# |    time_elapsed     | 439      |
# |    total_timesteps  | 85946    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.574    |
# |    n_updates        | 20236    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 194      |
# |    time_elapsed     | 452      |
# |    total_timesteps  | 88282    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.181    |
# |    n_updates        | 20820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 194      |
# |    time_elapsed     | 469      |
# |    total_timesteps  | 91221    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.392    |
# |    n_updates        | 21555    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 193      |
# |    time_elapsed     | 482      |
# |    total_timesteps  | 93350    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.323    |
# |    n_updates        | 22087    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 192      |
# |    time_elapsed     | 497      |
# |    total_timesteps  | 95994    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.65     |
# |    n_updates        | 22748    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 192      |
# |    time_elapsed     | 512      |
# |    total_timesteps  | 98508    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.208    |
# |    n_updates        | 23376    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 191      |
# |    time_elapsed     | 532      |
# |    total_timesteps  | 102006   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.484    |
# |    n_updates        | 24251    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 191      |
# |    time_elapsed     | 544      |
# |    total_timesteps  | 104073   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.632    |
# |    n_updates        | 24768    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 190      |
# |    time_elapsed     | 558      |
# |    total_timesteps  | 106484   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.411    |
# |    n_updates        | 25370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 190      |
# |    time_elapsed     | 573      |
# |    total_timesteps  | 109143   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.809    |
# |    n_updates        | 26035    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 189      |
# |    time_elapsed     | 585      |
# |    total_timesteps  | 111160   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.443    |
# |    n_updates        | 26539    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 189      |
# |    time_elapsed     | 597      |
# |    total_timesteps  | 113197   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.672    |
# |    n_updates        | 27049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 189      |
# |    time_elapsed     | 614      |
# |    total_timesteps  | 116202   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.222    |
# |    n_updates        | 27800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 188      |
# |    time_elapsed     | 628      |
# |    total_timesteps  | 118676   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.269    |
# |    n_updates        | 28418    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 188      |
# |    time_elapsed     | 641      |
# |    total_timesteps  | 120812   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.17     |
# |    n_updates        | 28952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 188      |
# |    time_elapsed     | 652      |
# |    total_timesteps  | 122709   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.301    |
# |    n_updates        | 29427    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 187      |
# |    time_elapsed     | 663      |
# |    total_timesteps  | 124731   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.495    |
# |    n_updates        | 29932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 187      |
# |    time_elapsed     | 679      |
# |    total_timesteps  | 127371   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.99     |
# |    n_updates        | 30592    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 187      |
# |    time_elapsed     | 692      |
# |    total_timesteps  | 129607   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.38     |
# |    n_updates        | 31151    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 187      |
# |    time_elapsed     | 706      |
# |    total_timesteps  | 132172   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.599    |
# |    n_updates        | 31792    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 186      |
# |    time_elapsed     | 724      |
# |    total_timesteps  | 135243   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.711    |
# |    n_updates        | 32560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 186      |
# |    time_elapsed     | 740      |
# |    total_timesteps  | 138009   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.342    |
# |    n_updates        | 33252    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 186      |
# |    time_elapsed     | 759      |
# |    total_timesteps  | 141354   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0623   |
# |    n_updates        | 34088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 185      |
# |    time_elapsed     | 771      |
# |    total_timesteps  | 143387   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.29     |
# |    n_updates        | 34596    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 185      |
# |    time_elapsed     | 788      |
# |    total_timesteps  | 146333   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.32     |
# |    n_updates        | 35333    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 185      |
# |    time_elapsed     | 803      |
# |    total_timesteps  | 148958   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.285    |
# |    n_updates        | 35989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 185      |
# |    time_elapsed     | 816      |
# |    total_timesteps  | 151229   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.552    |
# |    n_updates        | 36557    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 185      |
# |    time_elapsed     | 832      |
# |    total_timesteps  | 153959   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.589    |
# |    n_updates        | 37239    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 184      |
# |    time_elapsed     | 847      |
# |    total_timesteps  | 156605   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.05     |
# |    n_updates        | 37901    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 184      |
# |    time_elapsed     | 866      |
# |    total_timesteps  | 159949   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.32     |
# |    n_updates        | 38737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 184      |
# |    time_elapsed     | 883      |
# |    total_timesteps  | 162946   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.729    |
# |    n_updates        | 39486    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 184      |
# |    time_elapsed     | 896      |
# |    total_timesteps  | 165122   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.71     |
# |    n_updates        | 40030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 183      |
# |    time_elapsed     | 913      |
# |    total_timesteps  | 168022   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.382    |
# |    n_updates        | 40755    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 183      |
# |    time_elapsed     | 925      |
# |    total_timesteps  | 170118   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.635    |
# |    n_updates        | 41279    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 183      |
# |    time_elapsed     | 937      |
# |    total_timesteps  | 172202   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.508    |
# |    n_updates        | 41800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 183      |
# |    time_elapsed     | 954      |
# |    total_timesteps  | 175119   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.669    |
# |    n_updates        | 42529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 183      |
# |    time_elapsed     | 972      |
# |    total_timesteps  | 178175   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.612    |
# |    n_updates        | 43293    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 182      |
# |    time_elapsed     | 991      |
# |    total_timesteps  | 181356   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.197    |
# |    n_updates        | 44088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 182      |
# |    time_elapsed     | 1005     |
# |    total_timesteps  | 183713   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.164    |
# |    n_updates        | 44678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 182      |
# |    time_elapsed     | 1019     |
# |    total_timesteps  | 186174   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.108    |
# |    n_updates        | 45293    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 182      |
# |    time_elapsed     | 1029     |
# |    total_timesteps  | 187974   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.792    |
# |    n_updates        | 45743    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 182      |
# |    time_elapsed     | 1043     |
# |    total_timesteps  | 190390   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.455    |
# |    n_updates        | 46347    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 182      |
# |    time_elapsed     | 1055     |
# |    total_timesteps  | 192578   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.825    |
# |    n_updates        | 46894    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 182      |
# |    time_elapsed     | 1069     |
# |    total_timesteps  | 194915   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.521    |
# |    n_updates        | 47478    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 182      |
# |    time_elapsed     | 1086     |
# |    total_timesteps  | 197757   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.427    |
# |    n_updates        | 48189    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 181      |
# |    time_elapsed     | 1103     |
# |    total_timesteps  | 200784   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.522    |
# |    n_updates        | 48945    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 181      |
# |    time_elapsed     | 1119     |
# |    total_timesteps  | 203598   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.822    |
# |    n_updates        | 49649    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 181      |
# |    time_elapsed     | 1132     |
# |    total_timesteps  | 205825   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.357    |
# |    n_updates        | 50206    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 181      |
# |    time_elapsed     | 1145     |
# |    total_timesteps  | 207996   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.377    |
# |    n_updates        | 50748    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 181      |
# |    time_elapsed     | 1161     |
# |    total_timesteps  | 210979   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.08     |
# |    n_updates        | 51494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 181      |
# |    time_elapsed     | 1173     |
# |    total_timesteps  | 213078   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.22     |
# |    n_updates        | 52019    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 181      |
# |    time_elapsed     | 1186     |
# |    total_timesteps  | 215403   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.06     |
# |    n_updates        | 52600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 181      |
# |    time_elapsed     | 1202     |
# |    total_timesteps  | 218250   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.484    |
# |    n_updates        | 53312    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 181      |
# |    time_elapsed     | 1216     |
# |    total_timesteps  | 220587   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.645    |
# |    n_updates        | 53896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 181      |
# |    time_elapsed     | 1231     |
# |    total_timesteps  | 223150   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.09     |
# |    n_updates        | 54537    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 181      |
# |    time_elapsed     | 1245     |
# |    total_timesteps  | 225593   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.43     |
# |    n_updates        | 55148    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 181      |
# |    time_elapsed     | 1262     |
# |    total_timesteps  | 228625   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.145    |
# |    n_updates        | 55906    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 181      |
# |    time_elapsed     | 1277     |
# |    total_timesteps  | 231434   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.408    |
# |    n_updates        | 56608    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 181      |
# |    time_elapsed     | 1289     |
# |    total_timesteps  | 233665   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.508    |
# |    n_updates        | 57166    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 181      |
# |    time_elapsed     | 1300     |
# |    total_timesteps  | 235542   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.551    |
# |    n_updates        | 57635    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 181      |
# |    time_elapsed     | 1316     |
# |    total_timesteps  | 238444   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.609    |
# |    n_updates        | 58360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 181      |
# |    time_elapsed     | 1334     |
# |    total_timesteps  | 241740   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.456    |
# |    n_updates        | 59184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 181      |
# |    time_elapsed     | 1351     |
# |    total_timesteps  | 244918   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.657    |
# |    n_updates        | 59979    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 181      |
# |    time_elapsed     | 1363     |
# |    total_timesteps  | 246929   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.615    |
# |    n_updates        | 60482    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 181      |
# |    time_elapsed     | 1379     |
# |    total_timesteps  | 249882   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.588    |
# |    n_updates        | 61220    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 181      |
# |    time_elapsed     | 1395     |
# |    total_timesteps  | 252731   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.607    |
# |    n_updates        | 61932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 181      |
# |    time_elapsed     | 1407     |
# |    total_timesteps  | 254852   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.952    |
# |    n_updates        | 62462    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 181      |
# |    time_elapsed     | 1421     |
# |    total_timesteps  | 257495   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.787    |
# |    n_updates        | 63123    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 181      |
# |    time_elapsed     | 1435     |
# |    total_timesteps  | 260023   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.434    |
# |    n_updates        | 63755    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 181      |
# |    time_elapsed     | 1450     |
# |    total_timesteps  | 262701   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.165    |
# |    n_updates        | 64425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 181      |
# |    time_elapsed     | 1466     |
# |    total_timesteps  | 265583   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.954    |
# |    n_updates        | 65145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 181      |
# |    time_elapsed     | 1478     |
# |    total_timesteps  | 267686   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.734    |
# |    n_updates        | 65671    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 181      |
# |    time_elapsed     | 1491     |
# |    total_timesteps  | 270194   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.182    |
# |    n_updates        | 66298    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 181      |
# |    time_elapsed     | 1504     |
# |    total_timesteps  | 272352   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.978    |
# |    n_updates        | 66837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 181      |
# |    time_elapsed     | 1521     |
# |    total_timesteps  | 275446   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.699    |
# |    n_updates        | 67611    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 181      |
# |    time_elapsed     | 1534     |
# |    total_timesteps  | 277776   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.597    |
# |    n_updates        | 68193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 181      |
# |    time_elapsed     | 1549     |
# |    total_timesteps  | 280581   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.436    |
# |    n_updates        | 68895    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 181      |
# |    time_elapsed     | 1564     |
# |    total_timesteps  | 283366   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.128    |
# |    n_updates        | 69591    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 181      |
# |    time_elapsed     | 1577     |
# |    total_timesteps  | 285720   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.422    |
# |    n_updates        | 70179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 181      |
# |    time_elapsed     | 1593     |
# |    total_timesteps  | 288573   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.791    |
# |    n_updates        | 70893    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 181      |
# |    time_elapsed     | 1611     |
# |    total_timesteps  | 291795   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.437    |
# |    n_updates        | 71698    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 181      |
# |    time_elapsed     | 1630     |
# |    total_timesteps  | 295281   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.509    |
# |    n_updates        | 72570    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 181      |
# |    time_elapsed     | 1649     |
# |    total_timesteps  | 298778   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.379    |
# |    n_updates        | 73444    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training Complete
# Mean Reward: 132.50 +/- 61.57
# Total Episodes: 490
# Model saved to: /kaggle/working/train-mlp-policy-3.zip
# Results saved to: /kaggle/working/train-mlp-policy-3-results.json

# %%
from IPython.display import FileLink
FileLink('train-mlp-policy-2.zip')
# Out:
# /kaggle/working/train-mlp-policy-2.zip
