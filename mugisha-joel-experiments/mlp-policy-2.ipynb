# %%
import subprocess
import sys

print("Installing dependencies for Kaggle environment...")

# Uninstall conflicting packages first
print("Removing conflicting packages...")
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "-q", "keras", "tensorflow"], 
               stderr=subprocess.DEVNULL)

# Install compatible versions
dependencies = [
    "numpy<2.0",
    "scipy<1.14",
    "protobuf<4.0",
    "tensorboard==2.15.0",
    "stable-baselines3[extra]==2.3.2",
    "ale-py==0.8.1",
    "gymnasium[atari,accept-rom-license]==0.29.1",
    "shimmy[atari]",
]

for dep in dependencies:
    print(f"Installing {dep}...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", dep])

print("\nAll dependencies installed successfully")
print("\nVerifying installation...")
try:
    import ale_py
    import gymnasium as gym
    from stable_baselines3 import DQN
    print("All imports successful!")
except Exception as e:
    print(f"Import error: {e}")
# Out:
# Installing dependencies for Kaggle environment...
# Removing conflicting packages...
# Installing numpy<2.0...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 80.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing scipy<1.14...
# Installing protobuf<4.0...
# Installing tensorboard==2.15.0...
# Installing stable-baselines3[extra]==2.3.2...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing ale-py==0.8.1...
# Installing gymnasium[atari,accept-rom-license]==0.29.1...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 13.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# kaggle-environments 1.18.0 requires gymnasium==0.29.0, but you have gymnasium 0.29.1 which is incompatible.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 0.2.1 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Installing shimmy[atari]...
#
# All dependencies installed successfully
#
# Verifying installation...
# All imports successful!

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import warnings
warnings.filterwarnings('ignore')

import ale_py
import gymnasium as gym
gym.register_envs(ale_py)
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np
import json
import torch
import gc

class LoggingCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(LoggingCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.current_reward = 0
        self.current_length = 0
        
    def _on_step(self):
        self.current_reward += self.locals['rewards'][0]
        self.current_length += 1
        
        if self.locals['dones'][0]:
            self.episode_rewards.append(self.current_reward)
            self.episode_lengths.append(self.current_length)
            self.current_reward = 0
            self.current_length = 0
            
            if len(self.episode_rewards) % 10 == 0:
                gc.collect()
                torch.cuda.empty_cache()
        return True

CONFIG = {
    "lr": 0.0005,
    "gamma": 0.95,
    "batch_size": 64,
    "eps_start": 1.0,
    "eps_end": 0.05,
    "eps_decay": 0.2,
    "policy": "MlpPolicy"
}

print(f"Training Configuration 2:")
print(f"Learning Rate: {CONFIG['lr']}")
print(f"Gamma: {CONFIG['gamma']}")
print(f"Batch Size: {CONFIG['batch_size']}")
print(f"Epsilon: {CONFIG['eps_start']} -> {CONFIG['eps_end']} (decay: {CONFIG['eps_decay']})")

gc.collect()
torch.cuda.empty_cache()

env = gym.make("ALE/SpaceInvaders-v5", frameskip=4)
env = DummyVecEnv([lambda: env])

model = DQN(
    CONFIG["policy"],
    env,
    learning_rate=CONFIG["lr"],
    gamma=CONFIG["gamma"],
    batch_size=CONFIG["batch_size"],
    buffer_size=20000,
    learning_starts=5000,
    exploration_initial_eps=CONFIG["eps_start"],
    exploration_final_eps=CONFIG["eps_end"],
    exploration_fraction=CONFIG["eps_decay"],
    target_update_interval=500,
    train_freq=4,
    gradient_steps=1,
    tensorboard_log="./logs/mlp-policy-2/",
    verbose=1,
    device="cuda" if torch.cuda.is_available() else "cpu"
)

callback = LoggingCallback()

model.learn(
    total_timesteps=300000,
    tb_log_name="SpaceInvaders_MlpPolicy_2",
    callback=callback,
    progress_bar=True
)

mean_reward, std_reward = evaluate_policy(
    model,
    env,
    n_eval_episodes=10,
    deterministic=True
)

results = {
    "config": CONFIG,
    "mean_reward": float(mean_reward),
    "std_reward": float(std_reward),
    "episode_rewards": [float(r) for r in callback.episode_rewards],
    "episode_lengths": [int(l) for l in callback.episode_lengths],
    "total_episodes": len(callback.episode_rewards)
}

model.save("/kaggle/working/train-mlp-policy-2")

with open("/kaggle/working/train-mlp-policy-2-results.json", "w") as f:
    json.dump(results, f, indent=2)

print(f"\nTraining Complete")
print(f"Mean Reward: {mean_reward:.2f} +/- {std_reward:.2f}")
print(f"Total Episodes: {len(callback.episode_rewards)}")
print(f"Model saved to: /kaggle/working/train-mlp-policy-2.zip")
print(f"Results saved to: /kaggle/working/train-mlp-policy-2-results.json")

env.close()
gc.collect()
torch.cuda.empty_cache()
# Out:
# Training Configuration 2:
# Learning Rate: 0.0005
# Gamma: 0.95
# Batch Size: 64
# Epsilon: 1.0 -> 0.05 (decay: 0.2)
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/mlp-policy-2/SpaceInvaders_MlpPolicy_2_1
# Output()
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 976      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2171     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 974      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3741     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 828      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5110     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.373    |
# |    n_updates        | 27       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 541      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 6964     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.308    |
# |    n_updates        | 490      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 442      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 8935     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.308    |
# |    n_updates        | 983      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 401      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 10779    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00342  |
# |    n_updates        | 1444     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 374      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 12666    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0239   |
# |    n_updates        | 1916     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.773    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 357      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 14355    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0275   |
# |    n_updates        | 2338     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.751    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 347      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 15756    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.082    |
# |    n_updates        | 2688     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.712    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 332      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 18205    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.22     |
# |    n_updates        | 3301     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.677    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 323      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 20431    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.621    |
# |    n_updates        | 3857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.638    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 316      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 22860    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00783  |
# |    n_updates        | 4464     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.605    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 311      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 24959    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.382    |
# |    n_updates        | 4989     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.568    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 306      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 27312    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.382    |
# |    n_updates        | 5577     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.537    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 302      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 29226    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.902    |
# |    n_updates        | 6056     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.483    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 297      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 32661    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0762   |
# |    n_updates        | 6915     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.441    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 293      |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 35297    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.464    |
# |    n_updates        | 7574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.408    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 290      |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 37371    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.686    |
# |    n_updates        | 8092     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.378    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 288      |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 39300    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0723   |
# |    n_updates        | 8574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.348    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 285      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 41201    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.308    |
# |    n_updates        | 9050     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.308    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 283      |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 43736    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00259  |
# |    n_updates        | 9683     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.264    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 280      |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 46457    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.15     |
# |    n_updates        | 10364    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.233    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 278      |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 48431    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.755    |
# |    n_updates        | 10857    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.195    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 276      |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 50850    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.556    |
# |    n_updates        | 11462    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.163    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 274      |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 52844    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.508    |
# |    n_updates        | 11960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.111    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 271      |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 56122    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.29     |
# |    n_updates        | 12780    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0721   |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 269      |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 58603    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00256  |
# |    n_updates        | 13400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 267      |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 61273    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.462    |
# |    n_updates        | 14068    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 253      |
# |    time_elapsed     | 363      |
# |    total_timesteps  | 92214    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.141    |
# |    n_updates        | 21803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 253      |
# |    time_elapsed     | 373      |
# |    total_timesteps  | 94552    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.387    |
# |    n_updates        | 22387    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 252      |
# |    time_elapsed     | 385      |
# |    total_timesteps  | 97330    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.86     |
# |    n_updates        | 23082    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 252      |
# |    time_elapsed     | 392      |
# |    total_timesteps  | 99007    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.017    |
# |    n_updates        | 23501    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 251      |
# |    time_elapsed     | 404      |
# |    total_timesteps  | 101817   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.27     |
# |    n_updates        | 24204    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 250      |
# |    time_elapsed     | 418      |
# |    total_timesteps  | 105056   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.963    |
# |    n_updates        | 25013    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 250      |
# |    time_elapsed     | 432      |
# |    total_timesteps  | 108169   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.407    |
# |    n_updates        | 25792    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 249      |
# |    time_elapsed     | 447      |
# |    total_timesteps  | 111677   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0286   |
# |    n_updates        | 26669    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 249      |
# |    time_elapsed     | 457      |
# |    total_timesteps  | 113992   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00952  |
# |    n_updates        | 27247    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 248      |
# |    time_elapsed     | 467      |
# |    total_timesteps  | 116286   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.458    |
# |    n_updates        | 27821    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 248      |
# |    time_elapsed     | 481      |
# |    total_timesteps  | 119414   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.762    |
# |    n_updates        | 28603    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 247      |
# |    time_elapsed     | 494      |
# |    total_timesteps  | 122649   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.828    |
# |    n_updates        | 29412    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 247      |
# |    time_elapsed     | 507      |
# |    total_timesteps  | 125618   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.234    |
# |    n_updates        | 30154    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 247      |
# |    time_elapsed     | 516      |
# |    total_timesteps  | 127691   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.5      |
# |    n_updates        | 30672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 246      |
# |    time_elapsed     | 525      |
# |    total_timesteps  | 129737   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.697    |
# |    n_updates        | 31184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 246      |
# |    time_elapsed     | 540      |
# |    total_timesteps  | 133076   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.293    |
# |    n_updates        | 32018    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 246      |
# |    time_elapsed     | 553      |
# |    total_timesteps  | 136125   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.521    |
# |    n_updates        | 32781    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 245      |
# |    time_elapsed     | 565      |
# |    total_timesteps  | 138972   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0912   |
# |    n_updates        | 33492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 245      |
# |    time_elapsed     | 578      |
# |    total_timesteps  | 141898   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0892   |
# |    n_updates        | 34224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 245      |
# |    time_elapsed     | 590      |
# |    total_timesteps  | 144866   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.629    |
# |    n_updates        | 34966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 244      |
# |    time_elapsed     | 601      |
# |    total_timesteps  | 147414   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0317   |
# |    n_updates        | 35603    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 244      |
# |    time_elapsed     | 613      |
# |    total_timesteps  | 150011   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.385    |
# |    n_updates        | 36252    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 244      |
# |    time_elapsed     | 625      |
# |    total_timesteps  | 152786   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0112   |
# |    n_updates        | 36946    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 244      |
# |    time_elapsed     | 636      |
# |    total_timesteps  | 155285   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.261    |
# |    n_updates        | 37571    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 244      |
# |    time_elapsed     | 644      |
# |    total_timesteps  | 157193   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0843   |
# |    n_updates        | 38048    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 243      |
# |    time_elapsed     | 657      |
# |    total_timesteps  | 160329   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.605    |
# |    n_updates        | 38832    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 243      |
# |    time_elapsed     | 668      |
# |    total_timesteps  | 162821   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.593    |
# |    n_updates        | 39455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 243      |
# |    time_elapsed     | 678      |
# |    total_timesteps  | 165170   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.525    |
# |    n_updates        | 40042    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 243      |
# |    time_elapsed     | 695      |
# |    total_timesteps  | 168972   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.467    |
# |    n_updates        | 40992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 242      |
# |    time_elapsed     | 705      |
# |    total_timesteps  | 171281   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.16     |
# |    n_updates        | 41570    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 242      |
# |    time_elapsed     | 713      |
# |    total_timesteps  | 173211   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.916    |
# |    n_updates        | 42052    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 242      |
# |    time_elapsed     | 721      |
# |    total_timesteps  | 175116   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.256    |
# |    n_updates        | 42528    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 242      |
# |    time_elapsed     | 733      |
# |    total_timesteps  | 177842   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.39     |
# |    n_updates        | 43210    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 242      |
# |    time_elapsed     | 743      |
# |    total_timesteps  | 180163   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.768    |
# |    n_updates        | 43790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 242      |
# |    time_elapsed     | 753      |
# |    total_timesteps  | 182473   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0449   |
# |    n_updates        | 44368    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 241      |
# |    time_elapsed     | 764      |
# |    total_timesteps  | 184872   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.147    |
# |    n_updates        | 44967    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 241      |
# |    time_elapsed     | 777      |
# |    total_timesteps  | 187889   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.524    |
# |    n_updates        | 45722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 241      |
# |    time_elapsed     | 788      |
# |    total_timesteps  | 190503   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00594  |
# |    n_updates        | 46375    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 241      |
# |    time_elapsed     | 802      |
# |    total_timesteps  | 193790   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0809   |
# |    n_updates        | 47197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 241      |
# |    time_elapsed     | 815      |
# |    total_timesteps  | 196674   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0734   |
# |    n_updates        | 47918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 241      |
# |    time_elapsed     | 828      |
# |    total_timesteps  | 199743   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0635   |
# |    n_updates        | 48685    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 240      |
# |    time_elapsed     | 839      |
# |    total_timesteps  | 202237   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.455    |
# |    n_updates        | 49309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 240      |
# |    time_elapsed     | 849      |
# |    total_timesteps  | 204507   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.226    |
# |    n_updates        | 49876    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 240      |
# |    time_elapsed     | 863      |
# |    total_timesteps  | 207746   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.148    |
# |    n_updates        | 50686    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 240      |
# |    time_elapsed     | 872      |
# |    total_timesteps  | 209809   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.215    |
# |    n_updates        | 51202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 240      |
# |    time_elapsed     | 887      |
# |    total_timesteps  | 213266   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.632    |
# |    n_updates        | 52066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 240      |
# |    time_elapsed     | 898      |
# |    total_timesteps  | 215846   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0865   |
# |    n_updates        | 52711    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 240      |
# |    time_elapsed     | 906      |
# |    total_timesteps  | 217652   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0052   |
# |    n_updates        | 53162    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 240      |
# |    time_elapsed     | 919      |
# |    total_timesteps  | 220657   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.605    |
# |    n_updates        | 53914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 239      |
# |    time_elapsed     | 935      |
# |    total_timesteps  | 224463   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.139    |
# |    n_updates        | 54865    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 239      |
# |    time_elapsed     | 948      |
# |    total_timesteps  | 227432   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0682   |
# |    n_updates        | 55607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 239      |
# |    time_elapsed     | 958      |
# |    total_timesteps  | 229725   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0568   |
# |    n_updates        | 56181    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 239      |
# |    time_elapsed     | 970      |
# |    total_timesteps  | 232471   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00207  |
# |    n_updates        | 56867    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 239      |
# |    time_elapsed     | 985      |
# |    total_timesteps  | 235849   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.1      |
# |    n_updates        | 57712    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 239      |
# |    time_elapsed     | 993      |
# |    total_timesteps  | 237849   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.484    |
# |    n_updates        | 58212    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 239      |
# |    time_elapsed     | 1004     |
# |    total_timesteps  | 240265   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.977    |
# |    n_updates        | 58816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 239      |
# |    time_elapsed     | 1013     |
# |    total_timesteps  | 242434   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.332    |
# |    n_updates        | 59358    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 239      |
# |    time_elapsed     | 1023     |
# |    total_timesteps  | 244749   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0345   |
# |    n_updates        | 59937    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 238      |
# |    time_elapsed     | 1038     |
# |    total_timesteps  | 248080   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0711   |
# |    n_updates        | 60769    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 238      |
# |    time_elapsed     | 1047     |
# |    total_timesteps  | 250178   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.384    |
# |    n_updates        | 61294    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 238      |
# |    time_elapsed     | 1058     |
# |    total_timesteps  | 252673   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.487    |
# |    n_updates        | 61918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 238      |
# |    time_elapsed     | 1071     |
# |    total_timesteps  | 255774   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.218    |
# |    n_updates        | 62693    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 238      |
# |    time_elapsed     | 1084     |
# |    total_timesteps  | 258697   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.308    |
# |    n_updates        | 63424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 238      |
# |    time_elapsed     | 1094     |
# |    total_timesteps  | 261106   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0968   |
# |    n_updates        | 64026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 238      |
# |    time_elapsed     | 1105     |
# |    total_timesteps  | 263618   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0111   |
# |    n_updates        | 64654    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 238      |
# |    time_elapsed     | 1115     |
# |    total_timesteps  | 265927   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.311    |
# |    n_updates        | 65231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 238      |
# |    time_elapsed     | 1130     |
# |    total_timesteps  | 269282   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.12     |
# |    n_updates        | 66070    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 238      |
# |    time_elapsed     | 1141     |
# |    total_timesteps  | 271764   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.497    |
# |    n_updates        | 66690    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 238      |
# |    time_elapsed     | 1150     |
# |    total_timesteps  | 274063   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.159    |
# |    n_updates        | 67265    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 238      |
# |    time_elapsed     | 1165     |
# |    total_timesteps  | 277464   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.693    |
# |    n_updates        | 68115    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 237      |
# |    time_elapsed     | 1174     |
# |    total_timesteps  | 279463   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.483    |
# |    n_updates        | 68615    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 237      |
# |    time_elapsed     | 1182     |
# |    total_timesteps  | 281309   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.15     |
# |    n_updates        | 69077    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 237      |
# |    time_elapsed     | 1197     |
# |    total_timesteps  | 284887   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.688    |
# |    n_updates        | 69971    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 237      |
# |    time_elapsed     | 1209     |
# |    total_timesteps  | 287641   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.154    |
# |    n_updates        | 70660    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 237      |
# |    time_elapsed     | 1223     |
# |    total_timesteps  | 290857   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.294    |
# |    n_updates        | 71464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 237      |
# |    time_elapsed     | 1235     |
# |    total_timesteps  | 293607   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.637    |
# |    n_updates        | 72151    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 237      |
# |    time_elapsed     | 1246     |
# |    total_timesteps  | 296173   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0149   |
# |    n_updates        | 72793    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 237      |
# |    time_elapsed     | 1254     |
# |    total_timesteps  | 297920   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.404    |
# |    n_updates        | 73229    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training Complete
# Mean Reward: 253.50 +/- 176.18
# Total Episodes: 463
# Model saved to: /kaggle/working/train-mlp-policy-2.zip
# Results saved to: /kaggle/working/train-mlp-policy-2-results.json

# %%
from IPython.display import FileLink
FileLink('train-mlp-policy-1.zip')
# Out:
# /kaggle/working/train-mlp-policy-1.zip
