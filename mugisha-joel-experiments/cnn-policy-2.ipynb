# %%
import subprocess
import sys

print("Installing dependencies for Kaggle environment...")

# Uninstall conflicting packages first
print("Removing conflicting packages...")
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "-q", "keras", "tensorflow"], 
               stderr=subprocess.DEVNULL)

# Install compatible versions
dependencies = [
    "numpy<2.0",
    "scipy<1.14",
    "protobuf<4.0",
    "tensorboard==2.15.0",
    "stable-baselines3[extra]==2.3.2",
    "ale-py==0.8.1",
    "gymnasium[atari,accept-rom-license]==0.29.1",
    "shimmy[atari]",
]

for dep in dependencies:
    print(f"Installing {dep}...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", dep])

print("\nAll dependencies installed successfully")
print("\nVerifying installation...")
try:
    import ale_py
    import gymnasium as gym
    from stable_baselines3 import DQN
    print("All imports successful!")
except Exception as e:
    print(f"Import error: {e}")
# Out:
# Installing dependencies for Kaggle environment...
# Removing conflicting packages...
# Installing numpy<2.0...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 78.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 1.1.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing scipy<1.14...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 48.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 1.1.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing protobuf<4.0...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 5.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# a2a-sdk 0.3.10 requires protobuf>=5.29.5, but you have protobuf 3.20.3 which is incompatible.
# ray 2.51.1 requires click!=8.3.0,>=7.0, but you have click 8.3.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# tensorflow-metadata 1.17.2 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 46.0.3 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.3.0 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# Installing tensorboard==2.15.0...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 53.8 MB/s eta 0:00:00
# Installing stable-baselines3[extra]==2.3.2...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 4.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing ale-py==0.8.1...
# Installing gymnasium[atari,accept-rom-license]==0.29.1...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 15.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# kaggle-environments 1.18.0 requires gymnasium==0.29.0, but you have gymnasium 0.29.1 which is incompatible.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 0.2.1 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Installing shimmy[atari]...
#
# All dependencies installed successfully
#
# Verifying installation...
# All imports successful!

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import warnings
warnings.filterwarnings('ignore')

import ale_py
import gymnasium as gym
gym.register_envs(ale_py)
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np
import json
import torch
import gc

class LoggingCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(LoggingCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.current_reward = 0
        self.current_length = 0
        
    def _on_step(self):
        self.current_reward += self.locals['rewards'][0]
        self.current_length += 1
        
        if self.locals['dones'][0]:
            self.episode_rewards.append(self.current_reward)
            self.episode_lengths.append(self.current_length)
            self.current_reward = 0
            self.current_length = 0
            
            if len(self.episode_rewards) % 10 == 0:
                gc.collect()
                torch.cuda.empty_cache()
        return True

CONFIG = {
    "lr": 0.00025,
    "gamma": 0.95,
    "batch_size": 32,
    "eps_start": 1.0,
    "eps_end": 0.01,
    "eps_decay": 0.5,
    "policy": "CnnPolicy"
}

print(f"Training Configuration 2:")
print(f"Learning Rate: {CONFIG['lr']}")
print(f"Gamma: {CONFIG['gamma']}")
print(f"Batch Size: {CONFIG['batch_size']}")
print(f"Epsilon: {CONFIG['eps_start']} -> {CONFIG['eps_end']} (decay: {CONFIG['eps_decay']})")

gc.collect()
torch.cuda.empty_cache()

env = gym.make("ALE/SpaceInvaders-v5", frameskip=4)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, n_stack=4)

model = DQN(
    CONFIG["policy"],
    env,
    learning_rate=CONFIG["lr"],
    gamma=CONFIG["gamma"],
    batch_size=CONFIG["batch_size"],
    buffer_size=20000,
    learning_starts=5000,
    exploration_initial_eps=CONFIG["eps_start"],
    exploration_final_eps=CONFIG["eps_end"],
    exploration_fraction=CONFIG["eps_decay"],
    target_update_interval=500,
    train_freq=4,
    gradient_steps=1,
    tensorboard_log="./logs/cnn-policy-2/",
    verbose=1,
    device="cuda" if torch.cuda.is_available() else "cpu"
)

callback = LoggingCallback()

model.learn(
    total_timesteps=300000,
    tb_log_name="SpaceInvaders_CnnPolicy_2",
    callback=callback,
    progress_bar=True
)

mean_reward, std_reward = evaluate_policy(
    model,
    env,
    n_eval_episodes=10,
    deterministic=True
)

results = {
    "config": CONFIG,
    "mean_reward": float(mean_reward),
    "std_reward": float(std_reward),
    "episode_rewards": [float(r) for r in callback.episode_rewards],
    "episode_lengths": [int(l) for l in callback.episode_lengths],
    "total_episodes": len(callback.episode_rewards)
}

model.save("/kaggle/working/train-cnn-policy-2")

with open("/kaggle/working/train-cnn-policy-2-results.json", "w") as f:
    json.dump(results, f, indent=2)

print(f"\nTraining Complete")
print(f"Mean Reward: {mean_reward:.2f} +/- {std_reward:.2f}")
print(f"Total Episodes: {len(callback.episode_rewards)}")
print(f"Model saved to: /kaggle/working/train-cnn-policy-2.zip")
print(f"Results saved to: /kaggle/working/train-cnn-policy-2-results.json")

env.close()
gc.collect()
torch.cuda.empty_cache()
# Out:
# Training Configuration 2:
# Learning Rate: 0.00025
# Gamma: 0.95
# Batch Size: 32
# Epsilon: 1.0 -> 0.01 (decay: 0.5)
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/cnn-policy-2/SpaceInvaders_CnnPolicy_2_1
# Output()
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 366      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2260     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 363      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 3834     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 293      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 5222     |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.142    |
# |    n_updates        | 55       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 205      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 6956     |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0015   |
# |    n_updates        | 488      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 169      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 8890     |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.000217 |
# |    n_updates        | 972      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 154      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 10716    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.452    |
# |    n_updates        | 1428     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 143      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 12893    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.00236  |
# |    n_updates        | 1973     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 136      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 14975    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0143   |
# |    n_updates        | 2493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 132      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 16705    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.55     |
# |    n_updates        | 2926     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 128      |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 18813    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.735    |
# |    n_updates        | 3453     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 125      |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 21060    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0216   |
# |    n_updates        | 4014     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 124      |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 23144    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0381   |
# |    n_updates        | 4535     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 123      |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 25419    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.181    |
# |    n_updates        | 5104     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 122      |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 27377    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.495    |
# |    n_updates        | 5594     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 121      |
# |    time_elapsed     | 244      |
# |    total_timesteps  | 29648    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.169    |
# |    n_updates        | 6161     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 120      |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 31127    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.091    |
# |    n_updates        | 6531     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 119      |
# |    time_elapsed     | 278      |
# |    total_timesteps  | 33386    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.664    |
# |    n_updates        | 7096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 119      |
# |    time_elapsed     | 296      |
# |    total_timesteps  | 35246    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.032    |
# |    n_updates        | 7561     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 118      |
# |    time_elapsed     | 312      |
# |    total_timesteps  | 37006    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.323    |
# |    n_updates        | 8001     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.741    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 117      |
# |    time_elapsed     | 332      |
# |    total_timesteps  | 39200    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 2.26     |
# |    n_updates        | 8549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 117      |
# |    time_elapsed     | 352      |
# |    total_timesteps  | 41337    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.049    |
# |    n_updates        | 9084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 116      |
# |    time_elapsed     | 371      |
# |    total_timesteps  | 43319    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.101    |
# |    n_updates        | 9579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.704    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 116      |
# |    time_elapsed     | 385      |
# |    total_timesteps  | 44846    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.06     |
# |    n_updates        | 9961     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.691    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 115      |
# |    time_elapsed     | 403      |
# |    total_timesteps  | 46763    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.21     |
# |    n_updates        | 10440    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.681    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 115      |
# |    time_elapsed     | 418      |
# |    total_timesteps  | 48351    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.488    |
# |    n_updates        | 10837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.667    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 114      |
# |    time_elapsed     | 438      |
# |    total_timesteps  | 50460    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.269    |
# |    n_updates        | 11364    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.651    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 114      |
# |    time_elapsed     | 461      |
# |    total_timesteps  | 52845    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.118    |
# |    n_updates        | 11961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.638    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 113      |
# |    time_elapsed     | 481      |
# |    total_timesteps  | 54841    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0582   |
# |    n_updates        | 12460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.621    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 113      |
# |    time_elapsed     | 505      |
# |    total_timesteps  | 57369    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.154    |
# |    n_updates        | 13092    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.608    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 113      |
# |    time_elapsed     | 525      |
# |    total_timesteps  | 59391    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.347    |
# |    n_updates        | 13597    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.595    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 112      |
# |    time_elapsed     | 545      |
# |    total_timesteps  | 61404    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.922    |
# |    n_updates        | 14100    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.582    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 112      |
# |    time_elapsed     | 564      |
# |    total_timesteps  | 63372    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.189    |
# |    n_updates        | 14592    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.565    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 111      |
# |    time_elapsed     | 590      |
# |    total_timesteps  | 65923    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0967   |
# |    n_updates        | 15230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.552    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 111      |
# |    time_elapsed     | 610      |
# |    total_timesteps  | 67933    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.831    |
# |    n_updates        | 15733    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.534    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 110      |
# |    time_elapsed     | 636      |
# |    total_timesteps  | 70542    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.184    |
# |    n_updates        | 16385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.518    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 110      |
# |    time_elapsed     | 660      |
# |    total_timesteps  | 73018    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.444    |
# |    n_updates        | 17004    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.503    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 110      |
# |    time_elapsed     | 683      |
# |    total_timesteps  | 75329    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.231    |
# |    n_updates        | 17582    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.488    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 109      |
# |    time_elapsed     | 706      |
# |    total_timesteps  | 77559    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0347   |
# |    n_updates        | 18139    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.471    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 109      |
# |    time_elapsed     | 732      |
# |    total_timesteps  | 80152    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.134    |
# |    n_updates        | 18787    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.456    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 109      |
# |    time_elapsed     | 754      |
# |    total_timesteps  | 82381    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.3      |
# |    n_updates        | 19345    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.44     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 108      |
# |    time_elapsed     | 780      |
# |    total_timesteps  | 84917    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.613    |
# |    n_updates        | 19979    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.423    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 108      |
# |    time_elapsed     | 805      |
# |    total_timesteps  | 87381    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.201    |
# |    n_updates        | 20595    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.409    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 108      |
# |    time_elapsed     | 828      |
# |    total_timesteps  | 89596    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.124    |
# |    n_updates        | 21148    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.393    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 107      |
# |    time_elapsed     | 853      |
# |    total_timesteps  | 92012    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.327    |
# |    n_updates        | 21752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.375    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 107      |
# |    time_elapsed     | 883      |
# |    total_timesteps  | 94767    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.996    |
# |    n_updates        | 22441    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.353    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 106      |
# |    time_elapsed     | 916      |
# |    total_timesteps  | 97999    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.178    |
# |    n_updates        | 23249    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.337    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 106      |
# |    time_elapsed     | 943      |
# |    total_timesteps  | 100483   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.422    |
# |    n_updates        | 23870    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.324    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 106      |
# |    time_elapsed     | 963      |
# |    total_timesteps  | 102378   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.365    |
# |    n_updates        | 24344    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.309    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 105      |
# |    time_elapsed     | 988      |
# |    total_timesteps  | 104723   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.179    |
# |    n_updates        | 24930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.29     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 105      |
# |    time_elapsed     | 1019     |
# |    total_timesteps  | 107627   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.217    |
# |    n_updates        | 25656    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.275    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 105      |
# |    time_elapsed     | 1042     |
# |    total_timesteps  | 109778   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.04     |
# |    n_updates        | 26194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.256    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 104      |
# |    time_elapsed     | 1075     |
# |    total_timesteps  | 112784   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.337    |
# |    n_updates        | 26945    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.242    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 104      |
# |    time_elapsed     | 1097     |
# |    total_timesteps  | 114864   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.331    |
# |    n_updates        | 27465    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.224    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 104      |
# |    time_elapsed     | 1126     |
# |    total_timesteps  | 117515   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.622    |
# |    n_updates        | 28128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.212    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 104      |
# |    time_elapsed     | 1147     |
# |    total_timesteps  | 119459   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.302    |
# |    n_updates        | 28614    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.193    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 103      |
# |    time_elapsed     | 1178     |
# |    total_timesteps  | 122270   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.323    |
# |    n_updates        | 29317    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.173    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 103      |
# |    time_elapsed     | 1211     |
# |    total_timesteps  | 125366   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.252    |
# |    n_updates        | 30091    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.157    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 103      |
# |    time_elapsed     | 1237     |
# |    total_timesteps  | 127729   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.787    |
# |    n_updates        | 30682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.143    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 102      |
# |    time_elapsed     | 1260     |
# |    total_timesteps  | 129854   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.741    |
# |    n_updates        | 31213    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.128    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 102      |
# |    time_elapsed     | 1287     |
# |    total_timesteps  | 132194   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.436    |
# |    n_updates        | 31798    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.111    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 102      |
# |    time_elapsed     | 1315     |
# |    total_timesteps  | 134734   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.665    |
# |    n_updates        | 32433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0937   |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 102      |
# |    time_elapsed     | 1343     |
# |    total_timesteps  | 137318   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.444    |
# |    n_updates        | 33079    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0766   |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 101      |
# |    time_elapsed     | 1373     |
# |    total_timesteps  | 139914   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.448    |
# |    n_updates        | 33728    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0587   |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 101      |
# |    time_elapsed     | 1403     |
# |    total_timesteps  | 142618   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.75     |
# |    n_updates        | 34404    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0414   |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 101      |
# |    time_elapsed     | 1433     |
# |    total_timesteps  | 145245   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.642    |
# |    n_updates        | 35061    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0222   |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 101      |
# |    time_elapsed     | 1465     |
# |    total_timesteps  | 148154   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.462    |
# |    n_updates        | 35788    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 100      |
# |    time_elapsed     | 1499     |
# |    total_timesteps  | 151156   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.151    |
# |    n_updates        | 36538    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 100      |
# |    time_elapsed     | 1531     |
# |    total_timesteps  | 153924   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.405    |
# |    n_updates        | 37230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 100      |
# |    time_elapsed     | 1566     |
# |    total_timesteps  | 157101   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.319    |
# |    n_updates        | 38025    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 100      |
# |    time_elapsed     | 1603     |
# |    total_timesteps  | 160365   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.21     |
# |    n_updates        | 38841    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 99       |
# |    time_elapsed     | 1635     |
# |    total_timesteps  | 163181   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.504    |
# |    n_updates        | 39545    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 99       |
# |    time_elapsed     | 1673     |
# |    total_timesteps  | 166576   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.686    |
# |    n_updates        | 40393    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 99       |
# |    time_elapsed     | 1705     |
# |    total_timesteps  | 169321   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.673    |
# |    n_updates        | 41080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 99       |
# |    time_elapsed     | 1740     |
# |    total_timesteps  | 172443   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.399    |
# |    n_updates        | 41860    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 98       |
# |    time_elapsed     | 1773     |
# |    total_timesteps  | 175257   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.34     |
# |    n_updates        | 42564    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 98       |
# |    time_elapsed     | 1806     |
# |    total_timesteps  | 178117   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.222    |
# |    n_updates        | 43279    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 98       |
# |    time_elapsed     | 1837     |
# |    total_timesteps  | 180703   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.259    |
# |    n_updates        | 43925    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 98       |
# |    time_elapsed     | 1868     |
# |    total_timesteps  | 183391   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.393    |
# |    n_updates        | 44597    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 97       |
# |    time_elapsed     | 1896     |
# |    total_timesteps  | 185800   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.231    |
# |    n_updates        | 45199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 97       |
# |    time_elapsed     | 1922     |
# |    total_timesteps  | 187979   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.42     |
# |    n_updates        | 45744    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 97       |
# |    time_elapsed     | 1955     |
# |    total_timesteps  | 190774   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0685   |
# |    n_updates        | 46443    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 97       |
# |    time_elapsed     | 1989     |
# |    total_timesteps  | 193556   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.345    |
# |    n_updates        | 47138    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 97       |
# |    time_elapsed     | 2022     |
# |    total_timesteps  | 196412   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.193    |
# |    n_updates        | 47852    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 96       |
# |    time_elapsed     | 2055     |
# |    total_timesteps  | 199213   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.966    |
# |    n_updates        | 48553    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 96       |
# |    time_elapsed     | 2084     |
# |    total_timesteps  | 201543   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.13     |
# |    n_updates        | 49135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 96       |
# |    time_elapsed     | 2111     |
# |    total_timesteps  | 203832   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.231    |
# |    n_updates        | 49707    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 96       |
# |    time_elapsed     | 2152     |
# |    total_timesteps  | 207457   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.245    |
# |    n_updates        | 50614    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 96       |
# |    time_elapsed     | 2187     |
# |    total_timesteps  | 210479   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.46     |
# |    n_updates        | 51369    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 96       |
# |    time_elapsed     | 2218     |
# |    total_timesteps  | 213116   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.255    |
# |    n_updates        | 52028    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 95       |
# |    time_elapsed     | 2250     |
# |    total_timesteps  | 215801   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.442    |
# |    n_updates        | 52700    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 95       |
# |    time_elapsed     | 2289     |
# |    total_timesteps  | 219143   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.475    |
# |    n_updates        | 53535    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 95       |
# |    time_elapsed     | 2329     |
# |    total_timesteps  | 222629   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.472    |
# |    n_updates        | 54407    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 95       |
# |    time_elapsed     | 2361     |
# |    total_timesteps  | 225340   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.555    |
# |    n_updates        | 55084    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 95       |
# |    time_elapsed     | 2379     |
# |    total_timesteps  | 226931   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.72     |
# |    n_updates        | 55482    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 95       |
# |    time_elapsed     | 2409     |
# |    total_timesteps  | 229548   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.213    |
# |    n_updates        | 56136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 95       |
# |    time_elapsed     | 2442     |
# |    total_timesteps  | 232485   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.193    |
# |    n_updates        | 56871    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 95       |
# |    time_elapsed     | 2470     |
# |    total_timesteps  | 234912   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.702    |
# |    n_updates        | 57477    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 94       |
# |    time_elapsed     | 2507     |
# |    total_timesteps  | 238146   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.141    |
# |    n_updates        | 58286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 94       |
# |    time_elapsed     | 2534     |
# |    total_timesteps  | 240532   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.415    |
# |    n_updates        | 58882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 94       |
# |    time_elapsed     | 2561     |
# |    total_timesteps  | 242860   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.292    |
# |    n_updates        | 59464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 94       |
# |    time_elapsed     | 2586     |
# |    total_timesteps  | 245105   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.185    |
# |    n_updates        | 60026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 94       |
# |    time_elapsed     | 2630     |
# |    total_timesteps  | 248941   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.895    |
# |    n_updates        | 60985    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 94       |
# |    time_elapsed     | 2658     |
# |    total_timesteps  | 251421   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.435    |
# |    n_updates        | 61605    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 94       |
# |    time_elapsed     | 2688     |
# |    total_timesteps  | 254051   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.53     |
# |    n_updates        | 62262    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 94       |
# |    time_elapsed     | 2718     |
# |    total_timesteps  | 256654   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.332    |
# |    n_updates        | 62913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 94       |
# |    time_elapsed     | 2748     |
# |    total_timesteps  | 259292   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.494    |
# |    n_updates        | 63572    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 94       |
# |    time_elapsed     | 2773     |
# |    total_timesteps  | 261528   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.142    |
# |    n_updates        | 64131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 94       |
# |    time_elapsed     | 2809     |
# |    total_timesteps  | 264653   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.474    |
# |    n_updates        | 64913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 94       |
# |    time_elapsed     | 2838     |
# |    total_timesteps  | 267190   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.258    |
# |    n_updates        | 65547    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 94       |
# |    time_elapsed     | 2863     |
# |    total_timesteps  | 269375   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0786   |
# |    n_updates        | 66093    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 94       |
# |    time_elapsed     | 2899     |
# |    total_timesteps  | 272551   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.127    |
# |    n_updates        | 66887    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 93       |
# |    time_elapsed     | 2933     |
# |    total_timesteps  | 275538   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.295    |
# |    n_updates        | 67634    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 93       |
# |    time_elapsed     | 2974     |
# |    total_timesteps  | 279137   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.504    |
# |    n_updates        | 68534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 93       |
# |    time_elapsed     | 3001     |
# |    total_timesteps  | 281496   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.199    |
# |    n_updates        | 69123    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 93       |
# |    time_elapsed     | 3028     |
# |    total_timesteps  | 283818   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.332    |
# |    n_updates        | 69704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 93       |
# |    time_elapsed     | 3055     |
# |    total_timesteps  | 286024   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.283    |
# |    n_updates        | 70255    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 93       |
# |    time_elapsed     | 3086     |
# |    total_timesteps  | 288698   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.622    |
# |    n_updates        | 70924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 93       |
# |    time_elapsed     | 3108     |
# |    total_timesteps  | 290550   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.5      |
# |    n_updates        | 71387    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 93       |
# |    time_elapsed     | 3134     |
# |    total_timesteps  | 292813   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.416    |
# |    n_updates        | 71953    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 93       |
# |    time_elapsed     | 3158     |
# |    total_timesteps  | 294877   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.442    |
# |    n_updates        | 72469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 93       |
# |    time_elapsed     | 3182     |
# |    total_timesteps  | 297024   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.24     |
# |    n_updates        | 73005    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 93       |
# |    time_elapsed     | 3208     |
# |    total_timesteps  | 299260   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.256    |
# |    n_updates        | 73564    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training Complete
# Mean Reward: 273.50 +/- 57.71
# Total Episodes: 489
# Model saved to: /kaggle/working/train-cnn-policy-2.zip
# Results saved to: /kaggle/working/train-cnn-policy-2-results.json

# %%
from IPython.display import FileLink
FileLink('train-cnn-policy-2.zip')
# Out:
# /kaggle/working/train-cnn-policy-1.zip
