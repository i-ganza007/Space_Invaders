# %%
import subprocess
import sys

print("Installing dependencies for Kaggle environment...")

# Uninstall conflicting packages first
print("Removing conflicting packages...")
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "-q", "keras", "tensorflow"], 
               stderr=subprocess.DEVNULL)

# Install compatible versions
dependencies = [
    "numpy<2.0",
    "scipy<1.14",
    "protobuf<4.0",
    "tensorboard==2.15.0",
    "stable-baselines3[extra]==2.3.2",
    "ale-py==0.8.1",
    "gymnasium[atari,accept-rom-license]==0.29.1",
    "shimmy[atari]",
]

for dep in dependencies:
    print(f"Installing {dep}...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", dep])

print("\nAll dependencies installed successfully")
print("\nVerifying installation...")
try:
    import ale_py
    import gymnasium as gym
    from stable_baselines3 import DQN
    print("All imports successful!")
except Exception as e:
    print(f"Import error: {e}")
# Out:
# Installing dependencies for Kaggle environment...
# Removing conflicting packages...
# Installing numpy<2.0...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 80.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing scipy<1.14...
# Installing protobuf<4.0...
# Installing tensorboard==2.15.0...
# Installing stable-baselines3[extra]==2.3.2...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing ale-py==0.8.1...
# Installing gymnasium[atari,accept-rom-license]==0.29.1...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 13.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# kaggle-environments 1.18.0 requires gymnasium==0.29.0, but you have gymnasium 0.29.1 which is incompatible.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 0.2.1 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Installing shimmy[atari]...
#
# All dependencies installed successfully
#
# Verifying installation...
# All imports successful!

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import warnings
warnings.filterwarnings('ignore')

import ale_py
import gymnasium as gym
gym.register_envs(ale_py)
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np
import json
import torch
import gc

class LoggingCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(LoggingCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.current_reward = 0
        self.current_length = 0
        
    def _on_step(self):
        self.current_reward += self.locals['rewards'][0]
        self.current_length += 1
        
        if self.locals['dones'][0]:
            self.episode_rewards.append(self.current_reward)
            self.episode_lengths.append(self.current_length)
            self.current_reward = 0
            self.current_length = 0
            
            if len(self.episode_rewards) % 10 == 0:
                gc.collect()
                torch.cuda.empty_cache()
        return True

CONFIG = {
    "lr": 0.0001,
    "gamma": 0.99,
    "batch_size": 32,
    "eps_start": 1.0,
    "eps_end": 0.01,
    "eps_decay": 0.1,
    "policy": "MlpPolicy"
}

print(f"Training Configuration 1:")
print(f"Learning Rate: {CONFIG['lr']}")
print(f"Gamma: {CONFIG['gamma']}")
print(f"Batch Size: {CONFIG['batch_size']}")
print(f"Epsilon: {CONFIG['eps_start']} -> {CONFIG['eps_end']} (decay: {CONFIG['eps_decay']})")

gc.collect()
torch.cuda.empty_cache()

env = gym.make("ALE/SpaceInvaders-v5", frameskip=4)
env = DummyVecEnv([lambda: env])

model = DQN(
    CONFIG["policy"],
    env,
    learning_rate=CONFIG["lr"],
    gamma=CONFIG["gamma"],
    batch_size=CONFIG["batch_size"],
    buffer_size=20000,
    learning_starts=5000,
    exploration_initial_eps=CONFIG["eps_start"],
    exploration_final_eps=CONFIG["eps_end"],
    exploration_fraction=CONFIG["eps_decay"],
    target_update_interval=500,
    train_freq=4,
    gradient_steps=1,
    tensorboard_log="./logs/mlp-policy-1/",
    verbose=1,
    device="cuda" if torch.cuda.is_available() else "cpu"
)

callback = LoggingCallback()

model.learn(
    total_timesteps=300000,
    tb_log_name="SpaceInvaders_MlpPolicy_1",
    callback=callback,
    progress_bar=True
)

mean_reward, std_reward = evaluate_policy(
    model,
    env,
    n_eval_episodes=10,
    deterministic=True
)

results = {
    "config": CONFIG,
    "mean_reward": float(mean_reward),
    "std_reward": float(std_reward),
    "episode_rewards": [float(r) for r in callback.episode_rewards],
    "episode_lengths": [int(l) for l in callback.episode_lengths],
    "total_episodes": len(callback.episode_rewards)
}

model.save("/kaggle/working/train-mlp-policy-1")

with open("/kaggle/working/train-mlp-policy-1-results.json", "w") as f:
    json.dump(results, f, indent=2)

print(f"\nTraining Complete")
print(f"Mean Reward: {mean_reward:.2f} +/- {std_reward:.2f}")
print(f"Total Episodes: {len(callback.episode_rewards)}")
print(f"Model saved to: /kaggle/working/train-mlp-policy-1.zip")
print(f"Results saved to: /kaggle/working/train-mlp-policy-1-results.json")

env.close()
gc.collect()
torch.cuda.empty_cache()
# Out:
# Training Configuration 1:
# Learning Rate: 0.0001
# Gamma: 0.99
# Batch Size: 32
# Epsilon: 1.0 -> 0.01 (decay: 0.1)
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/mlp-policy-1/SpaceInvaders_MlpPolicy_1_1
# Output()
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 891      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1926     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 939      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4104     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 688      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 5968     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.14     |
# |    n_updates        | 241      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.746    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 566      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 7705     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.765    |
# |    n_updates        | 676      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.674    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 491      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 9883     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.142    |
# |    n_updates        | 1220     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.599    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 450      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 12153    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.35     |
# |    n_updates        | 1788     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.522    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 422      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 14485    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.772    |
# |    n_updates        | 2371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.416    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 395      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 17685    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00529  |
# |    n_updates        | 3171     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.36     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 384      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 19400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 3599     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.303    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 375      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 21109    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.603    |
# |    n_updates        | 4027     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.228    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 366      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 23406    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.143    |
# |    n_updates        | 4601     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.14     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 357      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 26052    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.457    |
# |    n_updates        | 5262     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0796   |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 350      |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 27891    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00501  |
# |    n_updates        | 5722     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 343      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 30371    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00379  |
# |    n_updates        | 6342     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 336      |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 33354    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00525  |
# |    n_updates        | 7088     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 330      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 36258    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.144    |
# |    n_updates        | 7814     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 327      |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 38404    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 8350     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 323      |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 41344    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.303    |
# |    n_updates        | 9085     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 320      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 43552    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 9637     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 317      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 46009    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.308    |
# |    n_updates        | 10252    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 314      |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 48907    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.348    |
# |    n_updates        | 10976    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 312      |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 51791    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.155    |
# |    n_updates        | 11697    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 310      |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 54092    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 12272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 308      |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 56964    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.493    |
# |    n_updates        | 12990    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 306      |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 59924    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.868    |
# |    n_updates        | 13730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 305      |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 62867    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 14466    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 304      |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 65601    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00256  |
# |    n_updates        | 15150    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 302      |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 68480    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.64     |
# |    n_updates        | 15869    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 301      |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 70778    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.51     |
# |    n_updates        | 16444    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 300      |
# |    time_elapsed     | 243      |
# |    total_timesteps  | 73371    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00382  |
# |    n_updates        | 17092    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 300      |
# |    time_elapsed     | 251      |
# |    total_timesteps  | 75564    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00776  |
# |    n_updates        | 17640    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 299      |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 77440    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.46     |
# |    n_updates        | 18109    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 298      |
# |    time_elapsed     | 271      |
# |    total_timesteps  | 81112    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 19027    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 297      |
# |    time_elapsed     | 282      |
# |    total_timesteps  | 83943    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00818  |
# |    n_updates        | 19735    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 296      |
# |    time_elapsed     | 292      |
# |    total_timesteps  | 86870    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00534  |
# |    n_updates        | 20467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 296      |
# |    time_elapsed     | 301      |
# |    total_timesteps  | 89216    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.604    |
# |    n_updates        | 21053    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 295      |
# |    time_elapsed     | 311      |
# |    total_timesteps  | 92129    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 21782    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 294      |
# |    time_elapsed     | 324      |
# |    total_timesteps  | 95574    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0223   |
# |    n_updates        | 22643    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 294      |
# |    time_elapsed     | 334      |
# |    total_timesteps  | 98548    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.141    |
# |    n_updates        | 23386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 293      |
# |    time_elapsed     | 343      |
# |    total_timesteps  | 101018   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.14     |
# |    n_updates        | 24004    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 293      |
# |    time_elapsed     | 354      |
# |    total_timesteps  | 103862   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00858  |
# |    n_updates        | 24715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 292      |
# |    time_elapsed     | 361      |
# |    total_timesteps  | 105927   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 25231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 292      |
# |    time_elapsed     | 371      |
# |    total_timesteps  | 108652   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.302    |
# |    n_updates        | 25912    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 292      |
# |    time_elapsed     | 382      |
# |    total_timesteps  | 111744   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.54     |
# |    n_updates        | 26685    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 291      |
# |    time_elapsed     | 389      |
# |    total_timesteps  | 113642   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.713    |
# |    n_updates        | 27160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 291      |
# |    time_elapsed     | 396      |
# |    total_timesteps  | 115527   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.448    |
# |    n_updates        | 27631    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 291      |
# |    time_elapsed     | 403      |
# |    total_timesteps  | 117623   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.457    |
# |    n_updates        | 28155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 290      |
# |    time_elapsed     | 411      |
# |    total_timesteps  | 119588   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00604  |
# |    n_updates        | 28646    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 290      |
# |    time_elapsed     | 420      |
# |    total_timesteps  | 122333   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00551  |
# |    n_updates        | 29333    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 290      |
# |    time_elapsed     | 431      |
# |    total_timesteps  | 125354   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0326   |
# |    n_updates        | 30088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 290      |
# |    time_elapsed     | 441      |
# |    total_timesteps  | 128017   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.005    |
# |    n_updates        | 30754    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 289      |
# |    time_elapsed     | 449      |
# |    total_timesteps  | 130244   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.802    |
# |    n_updates        | 31310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 289      |
# |    time_elapsed     | 458      |
# |    total_timesteps  | 132860   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0139   |
# |    n_updates        | 31964    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 289      |
# |    time_elapsed     | 467      |
# |    total_timesteps  | 135317   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0354   |
# |    n_updates        | 32579    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 289      |
# |    time_elapsed     | 477      |
# |    total_timesteps  | 137991   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00452  |
# |    n_updates        | 33247    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 288      |
# |    time_elapsed     | 485      |
# |    total_timesteps  | 140245   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.617    |
# |    n_updates        | 33811    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 288      |
# |    time_elapsed     | 494      |
# |    total_timesteps  | 142668   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00834  |
# |    n_updates        | 34416    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 288      |
# |    time_elapsed     | 500      |
# |    total_timesteps  | 144350   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00947  |
# |    n_updates        | 34837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 288      |
# |    time_elapsed     | 511      |
# |    total_timesteps  | 147277   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0105   |
# |    n_updates        | 35569    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 287      |
# |    time_elapsed     | 521      |
# |    total_timesteps  | 150094   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.435    |
# |    n_updates        | 36273    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 287      |
# |    time_elapsed     | 531      |
# |    total_timesteps  | 152819   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00551  |
# |    n_updates        | 36954    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 287      |
# |    time_elapsed     | 540      |
# |    total_timesteps  | 155308   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00792  |
# |    n_updates        | 37576    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 287      |
# |    time_elapsed     | 547      |
# |    total_timesteps  | 157216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00737  |
# |    n_updates        | 38053    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 286      |
# |    time_elapsed     | 556      |
# |    total_timesteps  | 159543   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.12     |
# |    n_updates        | 38635    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 286      |
# |    time_elapsed     | 566      |
# |    total_timesteps  | 162245   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.625    |
# |    n_updates        | 39311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 286      |
# |    time_elapsed     | 576      |
# |    total_timesteps  | 165039   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.16     |
# |    n_updates        | 40009    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 286      |
# |    time_elapsed     | 586      |
# |    total_timesteps  | 167668   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 40666    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 285      |
# |    time_elapsed     | 594      |
# |    total_timesteps  | 169825   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.606    |
# |    n_updates        | 41206    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 285      |
# |    time_elapsed     | 602      |
# |    total_timesteps  | 172190   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.909    |
# |    n_updates        | 41797    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 285      |
# |    time_elapsed     | 611      |
# |    total_timesteps  | 174345   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 42336    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 285      |
# |    time_elapsed     | 621      |
# |    total_timesteps  | 177302   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.145    |
# |    n_updates        | 43075    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 284      |
# |    time_elapsed     | 630      |
# |    total_timesteps  | 179545   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0061   |
# |    n_updates        | 43636    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 284      |
# |    time_elapsed     | 636      |
# |    total_timesteps  | 181337   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0135   |
# |    n_updates        | 44084    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 284      |
# |    time_elapsed     | 643      |
# |    total_timesteps  | 183212   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 44552    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 284      |
# |    time_elapsed     | 654      |
# |    total_timesteps  | 186172   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00821  |
# |    n_updates        | 45292    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 284      |
# |    time_elapsed     | 662      |
# |    total_timesteps  | 188230   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.103    |
# |    n_updates        | 45807    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 284      |
# |    time_elapsed     | 672      |
# |    total_timesteps  | 190944   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00298  |
# |    n_updates        | 46485    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 283      |
# |    time_elapsed     | 681      |
# |    total_timesteps  | 193467   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.471    |
# |    n_updates        | 47116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 283      |
# |    time_elapsed     | 689      |
# |    total_timesteps  | 195663   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.919    |
# |    n_updates        | 47665    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 283      |
# |    time_elapsed     | 697      |
# |    total_timesteps  | 197851   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.305    |
# |    n_updates        | 48212    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 283      |
# |    time_elapsed     | 709      |
# |    total_timesteps  | 200992   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19     |
# |    n_updates        | 48997    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 283      |
# |    time_elapsed     | 720      |
# |    total_timesteps  | 204089   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.128    |
# |    n_updates        | 49772    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 283      |
# |    time_elapsed     | 729      |
# |    total_timesteps  | 206483   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0972   |
# |    n_updates        | 50370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 282      |
# |    time_elapsed     | 737      |
# |    total_timesteps  | 208647   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.51     |
# |    n_updates        | 50911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 282      |
# |    time_elapsed     | 746      |
# |    total_timesteps  | 211014   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08     |
# |    n_updates        | 51503    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 282      |
# |    time_elapsed     | 754      |
# |    total_timesteps  | 213116   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.15     |
# |    n_updates        | 52028    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 282      |
# |    time_elapsed     | 764      |
# |    total_timesteps  | 215970   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.311    |
# |    n_updates        | 52742    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 282      |
# |    time_elapsed     | 773      |
# |    total_timesteps  | 218335   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.766    |
# |    n_updates        | 53333    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 282      |
# |    time_elapsed     | 784      |
# |    total_timesteps  | 221375   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.606    |
# |    n_updates        | 54093    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 281      |
# |    time_elapsed     | 796      |
# |    total_timesteps  | 224630   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0329   |
# |    n_updates        | 54907    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 281      |
# |    time_elapsed     | 806      |
# |    total_timesteps  | 227243   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0293   |
# |    n_updates        | 55560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 281      |
# |    time_elapsed     | 815      |
# |    total_timesteps  | 229751   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.142    |
# |    n_updates        | 56187    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 281      |
# |    time_elapsed     | 824      |
# |    total_timesteps  | 232280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.964    |
# |    n_updates        | 56819    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 281      |
# |    time_elapsed     | 834      |
# |    total_timesteps  | 234911   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0614   |
# |    n_updates        | 57477    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 281      |
# |    time_elapsed     | 843      |
# |    total_timesteps  | 237114   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.176    |
# |    n_updates        | 58028    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 281      |
# |    time_elapsed     | 853      |
# |    total_timesteps  | 239963   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.33     |
# |    n_updates        | 58740    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 281      |
# |    time_elapsed     | 861      |
# |    total_timesteps  | 242244   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.2      |
# |    n_updates        | 59310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 280      |
# |    time_elapsed     | 871      |
# |    total_timesteps  | 244855   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.121    |
# |    n_updates        | 59963    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 280      |
# |    time_elapsed     | 880      |
# |    total_timesteps  | 247255   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.861    |
# |    n_updates        | 60563    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 280      |
# |    time_elapsed     | 892      |
# |    total_timesteps  | 250492   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0485   |
# |    n_updates        | 61372    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 280      |
# |    time_elapsed     | 900      |
# |    total_timesteps  | 252648   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.008    |
# |    n_updates        | 61911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 280      |
# |    time_elapsed     | 910      |
# |    total_timesteps  | 255436   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.126    |
# |    n_updates        | 62608    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 280      |
# |    time_elapsed     | 918      |
# |    total_timesteps  | 257701   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.236    |
# |    n_updates        | 63175    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 280      |
# |    time_elapsed     | 926      |
# |    total_timesteps  | 259875   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19     |
# |    n_updates        | 63718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 280      |
# |    time_elapsed     | 937      |
# |    total_timesteps  | 262804   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.639    |
# |    n_updates        | 64450    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 280      |
# |    time_elapsed     | 945      |
# |    total_timesteps  | 265008   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.124    |
# |    n_updates        | 65001    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 280      |
# |    time_elapsed     | 954      |
# |    total_timesteps  | 267373   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 65593    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 280      |
# |    time_elapsed     | 963      |
# |    total_timesteps  | 270069   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.72     |
# |    n_updates        | 66267    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 280      |
# |    time_elapsed     | 973      |
# |    total_timesteps  | 272834   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.129    |
# |    n_updates        | 66958    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 280      |
# |    time_elapsed     | 982      |
# |    total_timesteps  | 275159   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.14     |
# |    n_updates        | 67539    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 280      |
# |    time_elapsed     | 991      |
# |    total_timesteps  | 277753   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.789    |
# |    n_updates        | 68188    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 280      |
# |    time_elapsed     | 1001     |
# |    total_timesteps  | 280493   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.999    |
# |    n_updates        | 68873    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 279      |
# |    time_elapsed     | 1011     |
# |    total_timesteps  | 283207   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 69551    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 279      |
# |    time_elapsed     | 1019     |
# |    total_timesteps  | 285308   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.322    |
# |    n_updates        | 70076    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 279      |
# |    time_elapsed     | 1029     |
# |    total_timesteps  | 288167   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0258   |
# |    n_updates        | 70791    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 279      |
# |    time_elapsed     | 1038     |
# |    total_timesteps  | 290504   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.028    |
# |    n_updates        | 71375    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 279      |
# |    time_elapsed     | 1047     |
# |    total_timesteps  | 293038   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0537   |
# |    n_updates        | 72009    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 279      |
# |    time_elapsed     | 1056     |
# |    total_timesteps  | 295612   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 72652    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 279      |
# |    time_elapsed     | 1065     |
# |    total_timesteps  | 298131   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0703   |
# |    n_updates        | 73282    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training Complete
# Mean Reward: 120.50 +/- 33.35
# Total Episodes: 478
# Model saved to: /kaggle/working/train-mlp-policy-1.zip
# Results saved to: /kaggle/working/train-mlp-policy-1-results.json

# %%
from IPython.display import FileLink
FileLink('train-cnn-policy-5.zip')
