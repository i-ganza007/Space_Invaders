# %%
import subprocess
import sys

print("Installing dependencies for Kaggle environment...")

# Uninstall conflicting packages first
print("Removing conflicting packages...")
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "-q", "keras", "tensorflow"], 
               stderr=subprocess.DEVNULL)

# Install compatible versions
dependencies = [
    "numpy<2.0",
    "scipy<1.14",
    "protobuf<4.0",
    "tensorboard==2.15.0",
    "stable-baselines3[extra]==2.3.2",
    "ale-py==0.8.1",
    "gymnasium[atari,accept-rom-license]==0.29.1",
    "shimmy[atari]",
]

for dep in dependencies:
    print(f"Installing {dep}...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", dep])

print("\nAll dependencies installed successfully")
print("\nVerifying installation...")
try:
    import ale_py
    import gymnasium as gym
    from stable_baselines3 import DQN
    print("All imports successful!")
except Exception as e:
    print(f"Import error: {e}")
# Out:
# Installing dependencies for Kaggle environment...
# Removing conflicting packages...
# Installing numpy<2.0...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 78.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 1.1.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing scipy<1.14...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 48.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 1.1.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing protobuf<4.0...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 5.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# a2a-sdk 0.3.10 requires protobuf>=5.29.5, but you have protobuf 3.20.3 which is incompatible.
# ray 2.51.1 requires click!=8.3.0,>=7.0, but you have click 8.3.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# tensorflow-metadata 1.17.2 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 46.0.3 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.3.0 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# Installing tensorboard==2.15.0...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 53.8 MB/s eta 0:00:00
# Installing stable-baselines3[extra]==2.3.2...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 4.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing ale-py==0.8.1...
# Installing gymnasium[atari,accept-rom-license]==0.29.1...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 15.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# kaggle-environments 1.18.0 requires gymnasium==0.29.0, but you have gymnasium 0.29.1 which is incompatible.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 0.2.1 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Installing shimmy[atari]...
#
# All dependencies installed successfully
#
# Verifying installation...
# All imports successful!

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import warnings
warnings.filterwarnings('ignore')

import ale_py
import gymnasium as gym
gym.register_envs(ale_py)
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np
import json
import torch
import gc

class LoggingCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(LoggingCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.current_reward = 0
        self.current_length = 0
        
    def _on_step(self):
        self.current_reward += self.locals['rewards'][0]
        self.current_length += 1
        
        if self.locals['dones'][0]:
            self.episode_rewards.append(self.current_reward)
            self.episode_lengths.append(self.current_length)
            self.current_reward = 0
            self.current_length = 0
            
            if len(self.episode_rewards) % 10 == 0:
                gc.collect()
                torch.cuda.empty_cache()
        return True

CONFIG = {
    "lr": 0.0005,
    "gamma": 0.99,
    "batch_size": 64,
    "eps_start": 1.0,
    "eps_end": 0.1,
    "eps_decay": 0.4,
    "policy": "CnnPolicy"
}

print(f"Training Configuration 3:")
print(f"Learning Rate: {CONFIG['lr']}")
print(f"Gamma: {CONFIG['gamma']}")
print(f"Batch Size: {CONFIG['batch_size']}")
print(f"Epsilon: {CONFIG['eps_start']} -> {CONFIG['eps_end']} (decay: {CONFIG['eps_decay']})")

gc.collect()
torch.cuda.empty_cache()

env = gym.make("ALE/SpaceInvaders-v5", frameskip=4)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, n_stack=4)

model = DQN(
    CONFIG["policy"],
    env,
    learning_rate=CONFIG["lr"],
    gamma=CONFIG["gamma"],
    batch_size=CONFIG["batch_size"],
    buffer_size=20000,
    learning_starts=5000,
    exploration_initial_eps=CONFIG["eps_start"],
    exploration_final_eps=CONFIG["eps_end"],
    exploration_fraction=CONFIG["eps_decay"],
    target_update_interval=500,
    train_freq=4,
    gradient_steps=1,
    tensorboard_log="./logs/cnn-policy-3/",
    verbose=1,
    device="cuda" if torch.cuda.is_available() else "cpu"
)

callback = LoggingCallback()

model.learn(
    total_timesteps=300000,
    tb_log_name="SpaceInvaders_CnnPolicy_3",
    callback=callback,
    progress_bar=True
)

mean_reward, std_reward = evaluate_policy(
    model,
    env,
    n_eval_episodes=10,
    deterministic=True
)

results = {
    "config": CONFIG,
    "mean_reward": float(mean_reward),
    "std_reward": float(std_reward),
    "episode_rewards": [float(r) for r in callback.episode_rewards],
    "episode_lengths": [int(l) for l in callback.episode_lengths],
    "total_episodes": len(callback.episode_rewards)
}

model.save("/kaggle/working/train-cnn-policy-3")

with open("/kaggle/working/train-cnn-policy-3-results.json", "w") as f:
    json.dump(results, f, indent=2)

print(f"\nTraining Complete")
print(f"Mean Reward: {mean_reward:.2f} +/- {std_reward:.2f}")
print(f"Total Episodes: {len(callback.episode_rewards)}")
print(f"Model saved to: /kaggle/working/train-cnn-policy-3.zip")
print(f"Results saved to: /kaggle/working/train-cnn-policy-3-results.json")

env.close()
gc.collect()
torch.cuda.empty_cache()
# Out:
# Training Configuration 3:
# Learning Rate: 0.0005
# Gamma: 0.99
# Batch Size: 64
# Epsilon: 1.0 -> 0.1 (decay: 0.4)
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/cnn-policy-3/SpaceInvaders_CnnPolicy_3_1
# Output()
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 354      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 1830     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 352      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 3329     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 295      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 5073     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.609    |
# |    n_updates        | 18       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 150      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 7308     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00124  |
# |    n_updates        | 576      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 114      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 9951     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.408    |
# |    n_updates        | 1237     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 103      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 12064    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0921   |
# |    n_updates        | 1765     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 96       |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 13912    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.372    |
# |    n_updates        | 2227     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 92       |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 15808    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.522    |
# |    n_updates        | 2701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 89       |
# |    time_elapsed     | 199      |
# |    total_timesteps  | 17790    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.89     |
# |    n_updates        | 3197     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 86       |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 19565    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.691    |
# |    n_updates        | 3641     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 84       |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 21753    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.59     |
# |    n_updates        | 4188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 83       |
# |    time_elapsed     | 277      |
# |    total_timesteps  | 23317    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.814    |
# |    n_updates        | 4579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 82       |
# |    time_elapsed     | 305      |
# |    total_timesteps  | 25279    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.838    |
# |    n_updates        | 5069     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 81       |
# |    time_elapsed     | 336      |
# |    total_timesteps  | 27467    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.647    |
# |    n_updates        | 5616     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 80       |
# |    time_elapsed     | 362      |
# |    total_timesteps  | 29298    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.879    |
# |    n_updates        | 6074     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.765    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 80       |
# |    time_elapsed     | 390      |
# |    total_timesteps  | 31326    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.779    |
# |    n_updates        | 6581     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 79       |
# |    time_elapsed     | 418      |
# |    total_timesteps  | 33304    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.24     |
# |    n_updates        | 7075     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.738    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 79       |
# |    time_elapsed     | 441      |
# |    total_timesteps  | 34938    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.797    |
# |    n_updates        | 7484     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.726    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 78       |
# |    time_elapsed     | 464      |
# |    total_timesteps  | 36552    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.01     |
# |    n_updates        | 7887     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.711    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 78       |
# |    time_elapsed     | 492      |
# |    total_timesteps  | 38476    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.3      |
# |    n_updates        | 8368     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 77       |
# |    time_elapsed     | 521      |
# |    total_timesteps  | 40481    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.901    |
# |    n_updates        | 8870     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.682    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 77       |
# |    time_elapsed     | 549      |
# |    total_timesteps  | 42418    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.878    |
# |    n_updates        | 9354     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.665    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 76       |
# |    time_elapsed     | 582      |
# |    total_timesteps  | 44708    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.997    |
# |    n_updates        | 9926     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.649    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 76       |
# |    time_elapsed     | 613      |
# |    total_timesteps  | 46844    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.06     |
# |    n_updates        | 10460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 76       |
# |    time_elapsed     | 645      |
# |    total_timesteps  | 49080    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.41     |
# |    n_updates        | 11019    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.614    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 75       |
# |    time_elapsed     | 679      |
# |    total_timesteps  | 51431    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.93     |
# |    n_updates        | 11607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.601    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 75       |
# |    time_elapsed     | 706      |
# |    total_timesteps  | 53258    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.55     |
# |    n_updates        | 12064    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.585    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 75       |
# |    time_elapsed     | 736      |
# |    total_timesteps  | 55315    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.29     |
# |    n_updates        | 12578    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.572    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 74       |
# |    time_elapsed     | 762      |
# |    total_timesteps  | 57104    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.868    |
# |    n_updates        | 13025    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 74       |
# |    time_elapsed     | 794      |
# |    total_timesteps  | 59304    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.978    |
# |    n_updates        | 13575    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.536    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 74       |
# |    time_elapsed     | 831      |
# |    total_timesteps  | 61824    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.19     |
# |    n_updates        | 14205    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.52     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 74       |
# |    time_elapsed     | 862      |
# |    total_timesteps  | 63950    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.81     |
# |    n_updates        | 14737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.503    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 73       |
# |    time_elapsed     | 896      |
# |    total_timesteps  | 66243    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.57     |
# |    n_updates        | 15310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.487    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 73       |
# |    time_elapsed     | 928      |
# |    total_timesteps  | 68401    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.11     |
# |    n_updates        | 15850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.466    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 73       |
# |    time_elapsed     | 970      |
# |    total_timesteps  | 71224    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.672    |
# |    n_updates        | 16555    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.45     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 73       |
# |    time_elapsed     | 1001     |
# |    total_timesteps  | 73271    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.27     |
# |    n_updates        | 17067    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.438    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 73       |
# |    time_elapsed     | 1025     |
# |    total_timesteps  | 74895    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.22     |
# |    n_updates        | 17473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.423    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 72       |
# |    time_elapsed     | 1056     |
# |    total_timesteps  | 76927    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.42     |
# |    n_updates        | 17981    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.406    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 72       |
# |    time_elapsed     | 1090     |
# |    total_timesteps  | 79135    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.5      |
# |    n_updates        | 18533    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.394    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 72       |
# |    time_elapsed     | 1115     |
# |    total_timesteps  | 80800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.888    |
# |    n_updates        | 18949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.378    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 72       |
# |    time_elapsed     | 1147     |
# |    total_timesteps  | 82901    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.44     |
# |    n_updates        | 19475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 72       |
# |    time_elapsed     | 1194     |
# |    total_timesteps  | 86032    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.58     |
# |    n_updates        | 20257    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.332    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 71       |
# |    time_elapsed     | 1240     |
# |    total_timesteps  | 89015    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.05     |
# |    n_updates        | 21003    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.317    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 71       |
# |    time_elapsed     | 1271     |
# |    total_timesteps  | 91058    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.37     |
# |    n_updates        | 21514    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.301    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 71       |
# |    time_elapsed     | 1303     |
# |    total_timesteps  | 93149    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.756    |
# |    n_updates        | 22037    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.285    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 71       |
# |    time_elapsed     | 1336     |
# |    total_timesteps  | 95328    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.59     |
# |    n_updates        | 22581    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 71       |
# |    time_elapsed     | 1365     |
# |    total_timesteps  | 97169    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.34     |
# |    n_updates        | 23042    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.257    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 71       |
# |    time_elapsed     | 1394     |
# |    total_timesteps  | 99033    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.32     |
# |    n_updates        | 23508    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.242    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 70       |
# |    time_elapsed     | 1424     |
# |    total_timesteps  | 101001   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.05     |
# |    n_updates        | 24000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.228    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 70       |
# |    time_elapsed     | 1455     |
# |    total_timesteps  | 102974   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.01     |
# |    n_updates        | 24493    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.212    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 70       |
# |    time_elapsed     | 1487     |
# |    total_timesteps  | 105097   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.47     |
# |    n_updates        | 25024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.197    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 70       |
# |    time_elapsed     | 1519     |
# |    total_timesteps  | 107121   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.44     |
# |    n_updates        | 25530    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.183    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 70       |
# |    time_elapsed     | 1547     |
# |    total_timesteps  | 108928   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.2      |
# |    n_updates        | 25981    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.166    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 70       |
# |    time_elapsed     | 1582     |
# |    total_timesteps  | 111164   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.45     |
# |    n_updates        | 26540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.153    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 70       |
# |    time_elapsed     | 1610     |
# |    total_timesteps  | 112895   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.35     |
# |    n_updates        | 26973    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.141    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 70       |
# |    time_elapsed     | 1636     |
# |    total_timesteps  | 114571   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.944    |
# |    n_updates        | 27392    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.122    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 69       |
# |    time_elapsed     | 1674     |
# |    total_timesteps  | 117020   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.64     |
# |    n_updates        | 28004    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.109    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 69       |
# |    time_elapsed     | 1703     |
# |    total_timesteps  | 118824   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.872    |
# |    n_updates        | 28455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 69       |
# |    time_elapsed     | 1726     |
# |    total_timesteps  | 120301   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.7      |
# |    n_updates        | 28825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 69       |
# |    time_elapsed     | 1769     |
# |    total_timesteps  | 122990   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.66     |
# |    n_updates        | 29497    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 69       |
# |    time_elapsed     | 1809     |
# |    total_timesteps  | 125527   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.87     |
# |    n_updates        | 30131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 69       |
# |    time_elapsed     | 1853     |
# |    total_timesteps  | 128318   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.784    |
# |    n_updates        | 30829    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 69       |
# |    time_elapsed     | 1883     |
# |    total_timesteps  | 130188   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.05     |
# |    n_updates        | 31296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 69       |
# |    time_elapsed     | 1912     |
# |    total_timesteps  | 132058   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.23     |
# |    n_updates        | 31764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 68       |
# |    time_elapsed     | 1943     |
# |    total_timesteps  | 133952   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.2      |
# |    n_updates        | 32237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 68       |
# |    time_elapsed     | 1969     |
# |    total_timesteps  | 135612   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.892    |
# |    n_updates        | 32652    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 68       |
# |    time_elapsed     | 2008     |
# |    total_timesteps  | 138090   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.796    |
# |    n_updates        | 33272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 68       |
# |    time_elapsed     | 2052     |
# |    total_timesteps  | 140845   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.02     |
# |    n_updates        | 33961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 68       |
# |    time_elapsed     | 2093     |
# |    total_timesteps  | 143457   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.35     |
# |    n_updates        | 34614    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 68       |
# |    time_elapsed     | 2141     |
# |    total_timesteps  | 146438   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.991    |
# |    n_updates        | 35359    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 68       |
# |    time_elapsed     | 2171     |
# |    total_timesteps  | 148266   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.85     |
# |    n_updates        | 35816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 68       |
# |    time_elapsed     | 2207     |
# |    total_timesteps  | 150533   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.03     |
# |    n_updates        | 36383    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 68       |
# |    time_elapsed     | 2259     |
# |    total_timesteps  | 153810   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.66     |
# |    n_updates        | 37202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 68       |
# |    time_elapsed     | 2291     |
# |    total_timesteps  | 155820   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.811    |
# |    n_updates        | 37704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 67       |
# |    time_elapsed     | 2342     |
# |    total_timesteps  | 159056   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.447    |
# |    n_updates        | 38513    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 67       |
# |    time_elapsed     | 2389     |
# |    total_timesteps  | 162015   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.85     |
# |    n_updates        | 39253    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 67       |
# |    time_elapsed     | 2423     |
# |    total_timesteps  | 164222   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.97     |
# |    n_updates        | 39805    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 67       |
# |    time_elapsed     | 2465     |
# |    total_timesteps  | 166813   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.571    |
# |    n_updates        | 40453    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 67       |
# |    time_elapsed     | 2497     |
# |    total_timesteps  | 168847   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.813    |
# |    n_updates        | 40961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 67       |
# |    time_elapsed     | 2549     |
# |    total_timesteps  | 172125   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.597    |
# |    n_updates        | 41781    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 67       |
# |    time_elapsed     | 2591     |
# |    total_timesteps  | 174781   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.617    |
# |    n_updates        | 42445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 67       |
# |    time_elapsed     | 2638     |
# |    total_timesteps  | 177746   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.851    |
# |    n_updates        | 43186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 67       |
# |    time_elapsed     | 2671     |
# |    total_timesteps  | 179822   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.43     |
# |    n_updates        | 43705    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 67       |
# |    time_elapsed     | 2712     |
# |    total_timesteps  | 182464   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.23     |
# |    n_updates        | 44365    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 67       |
# |    time_elapsed     | 2751     |
# |    total_timesteps  | 184891   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.678    |
# |    n_updates        | 44972    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 67       |
# |    time_elapsed     | 2792     |
# |    total_timesteps  | 187513   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.32     |
# |    n_updates        | 45628    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 67       |
# |    time_elapsed     | 2823     |
# |    total_timesteps  | 189425   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2        |
# |    n_updates        | 46106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 67       |
# |    time_elapsed     | 2852     |
# |    total_timesteps  | 191249   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.12     |
# |    n_updates        | 46562    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 66       |
# |    time_elapsed     | 2891     |
# |    total_timesteps  | 193722   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.882    |
# |    n_updates        | 47180    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 66       |
# |    time_elapsed     | 2937     |
# |    total_timesteps  | 196585   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.944    |
# |    n_updates        | 47896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 66       |
# |    time_elapsed     | 2986     |
# |    total_timesteps  | 199663   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.18     |
# |    n_updates        | 48665    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 66       |
# |    time_elapsed     | 3023     |
# |    total_timesteps  | 202005   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.7      |
# |    n_updates        | 49251    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 66       |
# |    time_elapsed     | 3052     |
# |    total_timesteps  | 203797   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.02     |
# |    n_updates        | 49699    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 66       |
# |    time_elapsed     | 3082     |
# |    total_timesteps  | 205707   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.07     |
# |    n_updates        | 50176    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 66       |
# |    time_elapsed     | 3132     |
# |    total_timesteps  | 208812   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.613    |
# |    n_updates        | 50952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 66       |
# |    time_elapsed     | 3173     |
# |    total_timesteps  | 211348   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.697    |
# |    n_updates        | 51586    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 66       |
# |    time_elapsed     | 3210     |
# |    total_timesteps  | 213659   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.624    |
# |    n_updates        | 52164    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 66       |
# |    time_elapsed     | 3240     |
# |    total_timesteps  | 215556   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.825    |
# |    n_updates        | 52638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 66       |
# |    time_elapsed     | 3284     |
# |    total_timesteps  | 218319   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.69     |
# |    n_updates        | 53329    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 66       |
# |    time_elapsed     | 3324     |
# |    total_timesteps  | 220819   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.03     |
# |    n_updates        | 53954    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 66       |
# |    time_elapsed     | 3379     |
# |    total_timesteps  | 224293   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.4      |
# |    n_updates        | 54823    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 66       |
# |    time_elapsed     | 3421     |
# |    total_timesteps  | 226942   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.2      |
# |    n_updates        | 55485    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 66       |
# |    time_elapsed     | 3460     |
# |    total_timesteps  | 229352   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.951    |
# |    n_updates        | 56087    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 66       |
# |    time_elapsed     | 3499     |
# |    total_timesteps  | 231862   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.45     |
# |    n_updates        | 56715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 66       |
# |    time_elapsed     | 3533     |
# |    total_timesteps  | 233954   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.7      |
# |    n_updates        | 57238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 66       |
# |    time_elapsed     | 3566     |
# |    total_timesteps  | 236026   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.98     |
# |    n_updates        | 57756    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 66       |
# |    time_elapsed     | 3601     |
# |    total_timesteps  | 238220   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.06     |
# |    n_updates        | 58304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 66       |
# |    time_elapsed     | 3640     |
# |    total_timesteps  | 240683   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.05     |
# |    n_updates        | 58920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 66       |
# |    time_elapsed     | 3672     |
# |    total_timesteps  | 242689   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.785    |
# |    n_updates        | 59422    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 66       |
# |    time_elapsed     | 3712     |
# |    total_timesteps  | 245239   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.9      |
# |    n_updates        | 60059    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 66       |
# |    time_elapsed     | 3737     |
# |    total_timesteps  | 246784   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 5.21     |
# |    n_updates        | 60445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 66       |
# |    time_elapsed     | 3767     |
# |    total_timesteps  | 248716   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.725    |
# |    n_updates        | 60928    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 65       |
# |    time_elapsed     | 3800     |
# |    total_timesteps  | 250724   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.13     |
# |    n_updates        | 61430    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 65       |
# |    time_elapsed     | 3943     |
# |    total_timesteps  | 259640   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.961    |
# |    n_updates        | 63659    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 65       |
# |    time_elapsed     | 3976     |
# |    total_timesteps  | 261712   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.953    |
# |    n_updates        | 64177    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 65       |
# |    time_elapsed     | 4016     |
# |    total_timesteps  | 264182   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.07     |
# |    n_updates        | 64795    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 65       |
# |    time_elapsed     | 4060     |
# |    total_timesteps  | 266911   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.748    |
# |    n_updates        | 65477    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 65       |
# |    time_elapsed     | 4090     |
# |    total_timesteps  | 268734   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.781    |
# |    n_updates        | 65933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 65       |
# |    time_elapsed     | 4124     |
# |    total_timesteps  | 270877   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.892    |
# |    n_updates        | 66469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 65       |
# |    time_elapsed     | 4156     |
# |    total_timesteps  | 272919   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.41     |
# |    n_updates        | 66979    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 65       |
# |    time_elapsed     | 4191     |
# |    total_timesteps  | 275081   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.5      |
# |    n_updates        | 67520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 65       |
# |    time_elapsed     | 4221     |
# |    total_timesteps  | 276978   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.04     |
# |    n_updates        | 67994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 65       |
# |    time_elapsed     | 4270     |
# |    total_timesteps  | 280034   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.37     |
# |    n_updates        | 68758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 65       |
# |    time_elapsed     | 4316     |
# |    total_timesteps  | 282976   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.76     |
# |    n_updates        | 69493    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 65       |
# |    time_elapsed     | 4366     |
# |    total_timesteps  | 286058   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.79     |
# |    n_updates        | 70264    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 65       |
# |    time_elapsed     | 4420     |
# |    total_timesteps  | 289429   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.63     |
# |    n_updates        | 71107    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 65       |
# |    time_elapsed     | 4474     |
# |    total_timesteps  | 292771   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.939    |
# |    n_updates        | 71942    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 65       |
# |    time_elapsed     | 4520     |
# |    total_timesteps  | 295590   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.07     |
# |    n_updates        | 72647    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 65       |
# |    time_elapsed     | 4569     |
# |    total_timesteps  | 298616   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.686    |
# |    n_updates        | 73403    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training Complete
# Mean Reward: 288.00 +/- 94.45
# Total Episodes: 526
# Model saved to: /kaggle/working/train-cnn-policy-3.zip
# Results saved to: /kaggle/working/train-cnn-policy-3-results.json

# %%
from IPython.display import FileLink
FileLink('train-cnn-policy-3.zip')
# Out:
# /kaggle/working/train-cnn-policy-2.zip
