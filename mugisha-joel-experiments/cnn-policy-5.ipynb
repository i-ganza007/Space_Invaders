# %%
import subprocess
import sys

print("Installing dependencies for Kaggle environment...")

# Uninstall conflicting packages first
print("Removing conflicting packages...")
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "-q", "keras", "tensorflow"], 
               stderr=subprocess.DEVNULL)

# Install compatible versions
dependencies = [
    "numpy<2.0",
    "scipy<1.14",
    "protobuf<4.0",
    "tensorboard==2.15.0",
    "stable-baselines3[extra]==2.3.2",
    "ale-py==0.8.1",
    "gymnasium[atari,accept-rom-license]==0.29.1",
    "shimmy[atari]",
]

for dep in dependencies:
    print(f"Installing {dep}...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", dep])

print("\nAll dependencies installed successfully")
print("\nVerifying installation...")
try:
    import ale_py
    import gymnasium as gym
    from stable_baselines3 import DQN
    print("All imports successful!")
except Exception as e:
    print(f"Import error: {e}")
# Out:
# Installing dependencies for Kaggle environment...
# Removing conflicting packages...
# Installing numpy<2.0...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 78.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 1.1.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing scipy<1.14...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 48.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 1.1.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing protobuf<4.0...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 5.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# a2a-sdk 0.3.10 requires protobuf>=5.29.5, but you have protobuf 3.20.3 which is incompatible.
# ray 2.51.1 requires click!=8.3.0,>=7.0, but you have click 8.3.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# tensorflow-metadata 1.17.2 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 46.0.3 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.3.0 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# Installing tensorboard==2.15.0...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 53.8 MB/s eta 0:00:00
# Installing stable-baselines3[extra]==2.3.2...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 4.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing ale-py==0.8.1...
# Installing gymnasium[atari,accept-rom-license]==0.29.1...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 15.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# kaggle-environments 1.18.0 requires gymnasium==0.29.0, but you have gymnasium 0.29.1 which is incompatible.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 0.2.1 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Installing shimmy[atari]...
#
# All dependencies installed successfully
#
# Verifying installation...
# All imports successful!

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import warnings
warnings.filterwarnings('ignore')

import ale_py
import gymnasium as gym
gym.register_envs(ale_py)
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np
import json
import torch
import gc

class LoggingCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(LoggingCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.current_reward = 0
        self.current_length = 0
        
    def _on_step(self):
        self.current_reward += self.locals['rewards'][0]
        self.current_length += 1
        
        if self.locals['dones'][0]:
            self.episode_rewards.append(self.current_reward)
            self.episode_lengths.append(self.current_length)
            self.current_reward = 0
            self.current_length = 0
            
            if len(self.episode_rewards) % 10 == 0:
                gc.collect()
                torch.cuda.empty_cache()
        return True

CONFIG = {
    "lr": 0.0001,
    "gamma": 0.97,
    "batch_size": 32,
    "eps_start": 0.9,
    "eps_end": 0.05,
    "eps_decay": 0.35,
    "policy": "CnnPolicy"
}

print(f"Training Configuration 5:")
print(f"Learning Rate: {CONFIG['lr']}")
print(f"Gamma: {CONFIG['gamma']}")
print(f"Batch Size: {CONFIG['batch_size']}")
print(f"Epsilon: {CONFIG['eps_start']} -> {CONFIG['eps_end']} (decay: {CONFIG['eps_decay']})")

gc.collect()
torch.cuda.empty_cache()

env = gym.make("ALE/SpaceInvaders-v5", frameskip=4)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, n_stack=4)

model = DQN(
    CONFIG["policy"],
    env,
    learning_rate=CONFIG["lr"],
    gamma=CONFIG["gamma"],
    batch_size=CONFIG["batch_size"],
    buffer_size=20000,
    learning_starts=5000,
    exploration_initial_eps=CONFIG["eps_start"],
    exploration_final_eps=CONFIG["eps_end"],
    exploration_fraction=CONFIG["eps_decay"],
    target_update_interval=500,
    train_freq=4,
    gradient_steps=1,
    tensorboard_log="./logs/cnn-policy-5/",
    verbose=1,
    device="cuda" if torch.cuda.is_available() else "cpu"
)

callback = LoggingCallback()

model.learn(
    total_timesteps=300000,
    tb_log_name="SpaceInvaders_CnnPolicy_5",
    callback=callback,
    progress_bar=True
)

mean_reward, std_reward = evaluate_policy(
    model,
    env,
    n_eval_episodes=10,
    deterministic=True
)

results = {
    "config": CONFIG,
    "mean_reward": float(mean_reward),
    "std_reward": float(std_reward),
    "episode_rewards": [float(r) for r in callback.episode_rewards],
    "episode_lengths": [int(l) for l in callback.episode_lengths],
    "total_episodes": len(callback.episode_rewards)
}

model.save("/kaggle/working/train-cnn-policy-5")

with open("/kaggle/working/train-cnn-policy-5-results.json", "w") as f:
    json.dump(results, f, indent=2)

print(f"\nTraining Complete")
print(f"Mean Reward: {mean_reward:.2f} +/- {std_reward:.2f}")
print(f"Total Episodes: {len(callback.episode_rewards)}")
print(f"Model saved to: /kaggle/working/train-cnn-policy-5.zip")
print(f"Results saved to: /kaggle/working/train-cnn-policy-5-results.json")
# Out:
# Training Configuration 5:
# Learning Rate: 0.0001
# Gamma: 0.97
# Batch Size: 32
# Epsilon: 0.9 -> 0.05 (decay: 0.35)
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/cnn-policy-5/SpaceInvaders_CnnPolicy_5_1
# Output()
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 360      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2201     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 361      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 4259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 246      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 6084     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000155 |
# |    n_updates        | 270      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 192      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 8332     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000629 |
# |    n_updates        | 832      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 173      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 10155    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000734 |
# |    n_updates        | 1288     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 162      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 11995    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00131  |
# |    n_updates        | 1748     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.779    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 152      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 14920    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00276  |
# |    n_updates        | 2479     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 146      |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 16965    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.145    |
# |    n_updates        | 2991     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 142      |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 19530    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.129    |
# |    n_updates        | 3632     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.72     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 139      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 22294    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00763  |
# |    n_updates        | 4323     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.699    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 138      |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 24846    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.628    |
# |    n_updates        | 4961     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.684    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 137      |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 26641    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.614    |
# |    n_updates        | 5410     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.667    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 135      |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 28810    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 5952     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.649    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 134      |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 30996    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 6498     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 133      |
# |    time_elapsed     | 251      |
# |    total_timesteps  | 33524    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 7130     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.615    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 132      |
# |    time_elapsed     | 265      |
# |    total_timesteps  | 35208    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.798    |
# |    n_updates        | 7551     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.599    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 132      |
# |    time_elapsed     | 281      |
# |    total_timesteps  | 37152    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 8037     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.583    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 131      |
# |    time_elapsed     | 298      |
# |    total_timesteps  | 39207    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.615    |
# |    n_updates        | 8551     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.567    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 130      |
# |    time_elapsed     | 315      |
# |    total_timesteps  | 41188    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0351   |
# |    n_updates        | 9046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.551    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 130      |
# |    time_elapsed     | 331      |
# |    total_timesteps  | 43146    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0222   |
# |    n_updates        | 9536     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.534    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 129      |
# |    time_elapsed     | 349      |
# |    total_timesteps  | 45265    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.162    |
# |    n_updates        | 10066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.517    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 129      |
# |    time_elapsed     | 366      |
# |    total_timesteps  | 47253    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0591   |
# |    n_updates        | 10563    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.5      |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 128      |
# |    time_elapsed     | 384      |
# |    total_timesteps  | 49362    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.11     |
# |    n_updates        | 11090    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.482    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 127      |
# |    time_elapsed     | 403      |
# |    total_timesteps  | 51651    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.79     |
# |    n_updates        | 11662    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.466    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 127      |
# |    time_elapsed     | 420      |
# |    total_timesteps  | 53584    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.596    |
# |    n_updates        | 12145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.448    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 127      |
# |    time_elapsed     | 439      |
# |    total_timesteps  | 55784    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.115    |
# |    n_updates        | 12695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.431    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 126      |
# |    time_elapsed     | 457      |
# |    total_timesteps  | 57879    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.286    |
# |    n_updates        | 13219    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.413    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 126      |
# |    time_elapsed     | 477      |
# |    total_timesteps  | 60162    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.143    |
# |    n_updates        | 13790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.395    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 125      |
# |    time_elapsed     | 496      |
# |    total_timesteps  | 62352    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.173    |
# |    n_updates        | 14337    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.377    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 125      |
# |    time_elapsed     | 516      |
# |    total_timesteps  | 64644    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.185    |
# |    n_updates        | 14910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.356    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 124      |
# |    time_elapsed     | 539      |
# |    total_timesteps  | 67230    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.856    |
# |    n_updates        | 15557    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.342    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 124      |
# |    time_elapsed     | 554      |
# |    total_timesteps  | 68952    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.756    |
# |    n_updates        | 15987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.319    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 123      |
# |    time_elapsed     | 579      |
# |    total_timesteps  | 71731    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.101    |
# |    n_updates        | 16682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.298    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 123      |
# |    time_elapsed     | 602      |
# |    total_timesteps  | 74319    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.69     |
# |    n_updates        | 17329    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.277    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 122      |
# |    time_elapsed     | 626      |
# |    total_timesteps  | 77000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.274    |
# |    n_updates        | 17999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.263    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 122      |
# |    time_elapsed     | 642      |
# |    total_timesteps  | 78716    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.121    |
# |    n_updates        | 18428    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.247    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 122      |
# |    time_elapsed     | 659      |
# |    total_timesteps  | 80659    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.34     |
# |    n_updates        | 18914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.229    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 121      |
# |    time_elapsed     | 680      |
# |    total_timesteps  | 82856    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.538    |
# |    n_updates        | 19463    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.21     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 121      |
# |    time_elapsed     | 704      |
# |    total_timesteps  | 85272    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.357    |
# |    n_updates        | 20067    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.192    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 120      |
# |    time_elapsed     | 725      |
# |    total_timesteps  | 87489    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.303    |
# |    n_updates        | 20622    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.177    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 120      |
# |    time_elapsed     | 742      |
# |    total_timesteps  | 89346    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0604   |
# |    n_updates        | 21086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.156    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 119      |
# |    time_elapsed     | 766      |
# |    total_timesteps  | 91857    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.472    |
# |    n_updates        | 21714    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.141    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 119      |
# |    time_elapsed     | 785      |
# |    total_timesteps  | 93788    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0944   |
# |    n_updates        | 22196    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.119    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 118      |
# |    time_elapsed     | 812      |
# |    total_timesteps  | 96521    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.117    |
# |    n_updates        | 22880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0979   |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 118      |
# |    time_elapsed     | 837      |
# |    total_timesteps  | 99084    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.94     |
# |    n_updates        | 23520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0761   |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 117      |
# |    time_elapsed     | 862      |
# |    total_timesteps  | 101772   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.8      |
# |    n_updates        | 24192    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 117      |
# |    time_elapsed     | 896      |
# |    total_timesteps  | 105298   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.06     |
# |    n_updates        | 25074    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 116      |
# |    time_elapsed     | 926      |
# |    total_timesteps  | 108364   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.168    |
# |    n_updates        | 25840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 116      |
# |    time_elapsed     | 951      |
# |    total_timesteps  | 110924   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.239    |
# |    n_updates        | 26480    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 116      |
# |    time_elapsed     | 977      |
# |    total_timesteps  | 113617   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.134    |
# |    n_updates        | 27154    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 115      |
# |    time_elapsed     | 1000     |
# |    total_timesteps  | 116047   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.605    |
# |    n_updates        | 27761    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 115      |
# |    time_elapsed     | 1024     |
# |    total_timesteps  | 118547   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 28386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 115      |
# |    time_elapsed     | 1051     |
# |    total_timesteps  | 121277   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0965   |
# |    n_updates        | 29069    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 115      |
# |    time_elapsed     | 1069     |
# |    total_timesteps  | 123193   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.113    |
# |    n_updates        | 29548    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 114      |
# |    time_elapsed     | 1092     |
# |    total_timesteps  | 125506   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.04     |
# |    n_updates        | 30126    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 114      |
# |    time_elapsed     | 1113     |
# |    total_timesteps  | 127721   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0292   |
# |    n_updates        | 30680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 114      |
# |    time_elapsed     | 1135     |
# |    total_timesteps  | 130033   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.305    |
# |    n_updates        | 31258    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 114      |
# |    time_elapsed     | 1161     |
# |    total_timesteps  | 132707   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.142    |
# |    n_updates        | 31926    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 114      |
# |    time_elapsed     | 1184     |
# |    total_timesteps  | 135192   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.175    |
# |    n_updates        | 32547    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 113      |
# |    time_elapsed     | 1206     |
# |    total_timesteps  | 137467   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.289    |
# |    n_updates        | 33116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 113      |
# |    time_elapsed     | 1239     |
# |    total_timesteps  | 140897   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.273    |
# |    n_updates        | 33974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 113      |
# |    time_elapsed     | 1272     |
# |    total_timesteps  | 144400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.162    |
# |    n_updates        | 34849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 113      |
# |    time_elapsed     | 1297     |
# |    total_timesteps  | 146965   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.271    |
# |    n_updates        | 35491    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 112      |
# |    time_elapsed     | 1331     |
# |    total_timesteps  | 150391   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.148    |
# |    n_updates        | 36347    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 112      |
# |    time_elapsed     | 1358     |
# |    total_timesteps  | 153016   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01     |
# |    n_updates        | 37003    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 112      |
# |    time_elapsed     | 1389     |
# |    total_timesteps  | 156175   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.47     |
# |    n_updates        | 37793    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 112      |
# |    time_elapsed     | 1418     |
# |    total_timesteps  | 159149   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.904    |
# |    n_updates        | 38537    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 112      |
# |    time_elapsed     | 1448     |
# |    total_timesteps  | 162228   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.268    |
# |    n_updates        | 39306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 111      |
# |    time_elapsed     | 1475     |
# |    total_timesteps  | 165076   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.496    |
# |    n_updates        | 40018    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 111      |
# |    time_elapsed     | 1508     |
# |    total_timesteps  | 168412   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.388    |
# |    n_updates        | 40852    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 111      |
# |    time_elapsed     | 1534     |
# |    total_timesteps  | 171158   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.04     |
# |    n_updates        | 41539    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 111      |
# |    time_elapsed     | 1568     |
# |    total_timesteps  | 174659   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.995    |
# |    n_updates        | 42414    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 111      |
# |    time_elapsed     | 1601     |
# |    total_timesteps  | 178063   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.925    |
# |    n_updates        | 43265    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 111      |
# |    time_elapsed     | 1624     |
# |    total_timesteps  | 180383   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0743   |
# |    n_updates        | 43845    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 110      |
# |    time_elapsed     | 1655     |
# |    total_timesteps  | 183507   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.792    |
# |    n_updates        | 44626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 110      |
# |    time_elapsed     | 1676     |
# |    total_timesteps  | 185643   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.271    |
# |    n_updates        | 45160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 110      |
# |    time_elapsed     | 1704     |
# |    total_timesteps  | 188518   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 45879    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 110      |
# |    time_elapsed     | 1730     |
# |    total_timesteps  | 191267   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.573    |
# |    n_updates        | 46566    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 110      |
# |    time_elapsed     | 1758     |
# |    total_timesteps  | 194217   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0556   |
# |    n_updates        | 47304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 110      |
# |    time_elapsed     | 1791     |
# |    total_timesteps  | 197622   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.14     |
# |    n_updates        | 48155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 110      |
# |    time_elapsed     | 1815     |
# |    total_timesteps  | 200191   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 48797    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 110      |
# |    time_elapsed     | 1845     |
# |    total_timesteps  | 203324   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.157    |
# |    n_updates        | 49580    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 110      |
# |    time_elapsed     | 1876     |
# |    total_timesteps  | 206537   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.861    |
# |    n_updates        | 50384    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 110      |
# |    time_elapsed     | 1902     |
# |    total_timesteps  | 209334   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.838    |
# |    n_updates        | 51083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 109      |
# |    time_elapsed     | 1926     |
# |    total_timesteps  | 211840   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 51709    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 109      |
# |    time_elapsed     | 1957     |
# |    total_timesteps  | 215057   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.434    |
# |    n_updates        | 52514    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 109      |
# |    time_elapsed     | 1986     |
# |    total_timesteps  | 218115   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.17     |
# |    n_updates        | 53278    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 109      |
# |    time_elapsed     | 2015     |
# |    total_timesteps  | 221121   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.257    |
# |    n_updates        | 54030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 109      |
# |    time_elapsed     | 2045     |
# |    total_timesteps  | 224181   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.17     |
# |    n_updates        | 54795    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 109      |
# |    time_elapsed     | 2079     |
# |    total_timesteps  | 227692   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.399    |
# |    n_updates        | 55672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 109      |
# |    time_elapsed     | 2106     |
# |    total_timesteps  | 230613   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.26     |
# |    n_updates        | 56403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 109      |
# |    time_elapsed     | 2141     |
# |    total_timesteps  | 234269   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.44     |
# |    n_updates        | 57317    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 109      |
# |    time_elapsed     | 2168     |
# |    total_timesteps  | 237061   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08     |
# |    n_updates        | 58015    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 109      |
# |    time_elapsed     | 2197     |
# |    total_timesteps  | 240064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.64     |
# |    n_updates        | 58765    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 109      |
# |    time_elapsed     | 2234     |
# |    total_timesteps  | 243925   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.331    |
# |    n_updates        | 59731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 109      |
# |    time_elapsed     | 2262     |
# |    total_timesteps  | 246810   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.844    |
# |    n_updates        | 60452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 109      |
# |    time_elapsed     | 2290     |
# |    total_timesteps  | 249770   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.172    |
# |    n_updates        | 61192    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 108      |
# |    time_elapsed     | 2310     |
# |    total_timesteps  | 251766   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.287    |
# |    n_updates        | 61691    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 108      |
# |    time_elapsed     | 2339     |
# |    total_timesteps  | 254826   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.494    |
# |    n_updates        | 62456    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 108      |
# |    time_elapsed     | 2365     |
# |    total_timesteps  | 257485   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.1      |
# |    n_updates        | 63121    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 108      |
# |    time_elapsed     | 2389     |
# |    total_timesteps  | 259998   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.476    |
# |    n_updates        | 63749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 108      |
# |    time_elapsed     | 2411     |
# |    total_timesteps  | 262281   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.269    |
# |    n_updates        | 64320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 108      |
# |    time_elapsed     | 2429     |
# |    total_timesteps  | 264208   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.438    |
# |    n_updates        | 64801    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 108      |
# |    time_elapsed     | 2458     |
# |    total_timesteps  | 267220   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.674    |
# |    n_updates        | 65554    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 108      |
# |    time_elapsed     | 2485     |
# |    total_timesteps  | 269929   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.414    |
# |    n_updates        | 66232    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 108      |
# |    time_elapsed     | 2511     |
# |    total_timesteps  | 272618   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 66904    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 108      |
# |    time_elapsed     | 2541     |
# |    total_timesteps  | 275772   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.258    |
# |    n_updates        | 67692    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 108      |
# |    time_elapsed     | 2567     |
# |    total_timesteps  | 278488   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.299    |
# |    n_updates        | 68371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 108      |
# |    time_elapsed     | 2600     |
# |    total_timesteps  | 281823   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.443    |
# |    n_updates        | 69205    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 108      |
# |    time_elapsed     | 2621     |
# |    total_timesteps  | 284060   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14     |
# |    n_updates        | 69764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 108      |
# |    time_elapsed     | 2655     |
# |    total_timesteps  | 287411   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.437    |
# |    n_updates        | 70602    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 108      |
# |    time_elapsed     | 2681     |
# |    total_timesteps  | 290126   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.324    |
# |    n_updates        | 71281    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 108      |
# |    time_elapsed     | 2706     |
# |    total_timesteps  | 292585   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.17     |
# |    n_updates        | 71896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 108      |
# |    time_elapsed     | 2734     |
# |    total_timesteps  | 295429   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.889    |
# |    n_updates        | 72607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 107      |
# |    time_elapsed     | 2759     |
# |    total_timesteps  | 298066   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.489    |
# |    n_updates        | 73266    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training Complete
# Mean Reward: 263.00 +/- 93.68
# Total Episodes: 462
# Model saved to: /kaggle/working/train-cnn-policy-5.zip
# Results saved to: /kaggle/working/train-cnn-policy-5-results.json

# %%
from IPython.display import FileLink
FileLink('train-cnn-policy-5.zip')
# Out:
# /kaggle/working/train-cnn-policy-5.zip
