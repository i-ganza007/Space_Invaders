# %%
import subprocess
import sys

print("Installing dependencies for Kaggle environment...")

# Uninstall conflicting packages first
print("Removing conflicting packages...")
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "-q", "keras", "tensorflow"], 
               stderr=subprocess.DEVNULL)

# Install compatible versions
dependencies = [
    "numpy<2.0",
    "scipy<1.14",
    "protobuf<4.0",
    "tensorboard==2.15.0",
    "stable-baselines3[extra]==2.3.2",
    "ale-py==0.8.1",
    "gymnasium[atari,accept-rom-license]==0.29.1",
    "shimmy[atari]",
]

for dep in dependencies:
    print(f"Installing {dep}...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", dep])

print("\nAll dependencies installed successfully")
print("\nVerifying installation...")
try:
    import ale_py
    import gymnasium as gym
    from stable_baselines3 import DQN
    print("All imports successful!")
except Exception as e:
    print(f"Import error: {e}")
# Out:
# Installing dependencies for Kaggle environment...
# Removing conflicting packages...
# Installing numpy<2.0...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 80.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing scipy<1.14...
# Installing protobuf<4.0...
# Installing tensorboard==2.15.0...
# Installing stable-baselines3[extra]==2.3.2...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing ale-py==0.8.1...
# Installing gymnasium[atari,accept-rom-license]==0.29.1...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 13.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# kaggle-environments 1.18.0 requires gymnasium==0.29.0, but you have gymnasium 0.29.1 which is incompatible.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 0.2.1 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Installing shimmy[atari]...
#
# All dependencies installed successfully
#
# Verifying installation...
# All imports successful!

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import warnings
warnings.filterwarnings('ignore')

import ale_py
import gymnasium as gym
gym.register_envs(ale_py)
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np
import json
import torch
import gc

class LoggingCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(LoggingCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.current_reward = 0
        self.current_length = 0
        
    def _on_step(self):
        self.current_reward += self.locals['rewards'][0]
        self.current_length += 1
        
        if self.locals['dones'][0]:
            self.episode_rewards.append(self.current_reward)
            self.episode_lengths.append(self.current_length)
            self.current_reward = 0
            self.current_length = 0
            
            if len(self.episode_rewards) % 10 == 0:
                gc.collect()
                torch.cuda.empty_cache()
        return True

CONFIG = {
    "lr": 0.001,
    "gamma": 0.98,
    "batch_size": 16,
    "eps_start": 1.0,
    "eps_end": 0.1,
    "eps_decay": 0.15,
    "policy": "MlpPolicy"
}

print(f"Training Configuration 4:")
print(f"Learning Rate: {CONFIG['lr']}")
print(f"Gamma: {CONFIG['gamma']}")
print(f"Batch Size: {CONFIG['batch_size']}")
print(f"Epsilon: {CONFIG['eps_start']} -> {CONFIG['eps_end']} (decay: {CONFIG['eps_decay']})")

gc.collect()
torch.cuda.empty_cache()

env = gym.make("ALE/SpaceInvaders-v5", frameskip=4)
env = DummyVecEnv([lambda: env])

model = DQN(
    CONFIG["policy"],
    env,
    learning_rate=CONFIG["lr"],
    gamma=CONFIG["gamma"],
    batch_size=CONFIG["batch_size"],
    buffer_size=20000,
    learning_starts=5000,
    exploration_initial_eps=CONFIG["eps_start"],
    exploration_final_eps=CONFIG["eps_end"],
    exploration_fraction=CONFIG["eps_decay"],
    target_update_interval=500,
    train_freq=4,
    gradient_steps=1,
    tensorboard_log="./logs/mlp-policy-4/",
    verbose=1,
    device="cuda" if torch.cuda.is_available() else "cpu"
)

callback = LoggingCallback()

model.learn(
    total_timesteps=300000,
    tb_log_name="SpaceInvaders_MlpPolicy_4",
    callback=callback,
    progress_bar=True
)

mean_reward, std_reward = evaluate_policy(
    model,
    env,
    n_eval_episodes=10,
    deterministic=True
)

results = {
    "config": CONFIG,
    "mean_reward": float(mean_reward),
    "std_reward": float(std_reward),
    "episode_rewards": [float(r) for r in callback.episode_rewards],
    "episode_lengths": [int(l) for l in callback.episode_lengths],
    "total_episodes": len(callback.episode_rewards)
}

model.save("/kaggle/working/train-mlp-policy-4")

with open("/kaggle/working/train-mlp-policy-4-results.json", "w") as f:
    json.dump(results, f, indent=2)

print(f"\nTraining Complete")
print(f"Mean Reward: {mean_reward:.2f} +/- {std_reward:.2f}")
print(f"Total Episodes: {len(callback.episode_rewards)}")
print(f"Model saved to: /kaggle/working/train-mlp-policy-4.zip")
print(f"Results saved to: /kaggle/working/train-mlp-policy-4-results.json")

env.close()
gc.collect()
torch.cuda.empty_cache()
# Out:
# Training Configuration 4:
# Learning Rate: 0.001
# Gamma: 0.98
# Batch Size: 16
# Epsilon: 1.0 -> 0.1 (decay: 0.15)
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/mlp-policy-4/SpaceInvaders_MlpPolicy_4_1
# Output()
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 984      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1817     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1001     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3970     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 789      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 5801     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000702 |
# |    n_updates        | 200      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 655      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 7773     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0143   |
# |    n_updates        | 693      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 586      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 9691     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.22     |
# |    n_updates        | 1172     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.757    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 543      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 12174    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00409  |
# |    n_updates        | 1793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 517      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 14314    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.281    |
# |    n_updates        | 2328     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.662    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 494      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 16900    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.109    |
# |    n_updates        | 2974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.622    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 480      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 18894    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00383  |
# |    n_updates        | 3473     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.578    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 468      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 21103    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000526 |
# |    n_updates        | 4025     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.541    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 462      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 22951    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0315   |
# |    n_updates        | 4487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.502    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 456      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 24923    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000655 |
# |    n_updates        | 4980     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.451    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 448      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 27454    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0201   |
# |    n_updates        | 5613     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.391    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 441      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 30434    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00543  |
# |    n_updates        | 6358     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.35     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 433      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 32487    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.15     |
# |    n_updates        | 6871     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.302    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 427      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 34894    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00184  |
# |    n_updates        | 7473     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.246    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 421      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 37687    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.23     |
# |    n_updates        | 8171     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.193    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 414      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 40361    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00309  |
# |    n_updates        | 8840     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.144    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 409      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 42824    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0165   |
# |    n_updates        | 9455     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 401      |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 46392    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00307  |
# |    n_updates        | 10347    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 398      |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 48336    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0149   |
# |    n_updates        | 10833    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 394      |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 50415    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000583 |
# |    n_updates        | 11353    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 389      |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 53603    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.069    |
# |    n_updates        | 12150    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 385      |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 56712    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00254  |
# |    n_updates        | 12927    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 381      |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 59884    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0145   |
# |    n_updates        | 13720    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 379      |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 61989    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.3      |
# |    n_updates        | 14247    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 377      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 64436    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00411  |
# |    n_updates        | 14858    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 375      |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 66488    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0116   |
# |    n_updates        | 15371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 372      |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 70648    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.258    |
# |    n_updates        | 16411    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 370      |
# |    time_elapsed     | 197      |
# |    total_timesteps  | 73410    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00132  |
# |    n_updates        | 17102    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 369      |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 75597    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00844  |
# |    n_updates        | 17649    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 367      |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 78359    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.235    |
# |    n_updates        | 18339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 365      |
# |    time_elapsed     | 222      |
# |    total_timesteps  | 81276    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.598    |
# |    n_updates        | 19068    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 363      |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 84166    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00419  |
# |    n_updates        | 19791    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 362      |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 87269    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0222   |
# |    n_updates        | 20567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 360      |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 89989    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.54     |
# |    n_updates        | 21247    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 359      |
# |    time_elapsed     | 259      |
# |    total_timesteps  | 93126    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00538  |
# |    n_updates        | 22031    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 358      |
# |    time_elapsed     | 267      |
# |    total_timesteps  | 95968    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.282    |
# |    n_updates        | 22741    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 357      |
# |    time_elapsed     | 276      |
# |    total_timesteps  | 98676    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00276  |
# |    n_updates        | 23418    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 356      |
# |    time_elapsed     | 285      |
# |    total_timesteps  | 101729   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00855  |
# |    n_updates        | 24182    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 355      |
# |    time_elapsed     | 293      |
# |    total_timesteps  | 104459   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0165   |
# |    n_updates        | 24864    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 354      |
# |    time_elapsed     | 301      |
# |    total_timesteps  | 107112   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0155   |
# |    n_updates        | 25527    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 354      |
# |    time_elapsed     | 307      |
# |    total_timesteps  | 108954   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00168  |
# |    n_updates        | 25988    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 353      |
# |    time_elapsed     | 317      |
# |    total_timesteps  | 112159   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0138   |
# |    n_updates        | 26789    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 352      |
# |    time_elapsed     | 326      |
# |    total_timesteps  | 115210   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0077   |
# |    n_updates        | 27552    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 351      |
# |    time_elapsed     | 333      |
# |    total_timesteps  | 117295   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00229  |
# |    n_updates        | 28073    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 351      |
# |    time_elapsed     | 341      |
# |    total_timesteps  | 120088   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00978  |
# |    n_updates        | 28771    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 350      |
# |    time_elapsed     | 349      |
# |    total_timesteps  | 122420   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00164  |
# |    n_updates        | 29354    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 350      |
# |    time_elapsed     | 357      |
# |    total_timesteps  | 125151   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000687 |
# |    n_updates        | 30037    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 349      |
# |    time_elapsed     | 363      |
# |    total_timesteps  | 126992   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000505 |
# |    n_updates        | 30497    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 349      |
# |    time_elapsed     | 370      |
# |    total_timesteps  | 129294   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00588  |
# |    n_updates        | 31073    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 348      |
# |    time_elapsed     | 380      |
# |    total_timesteps  | 132643   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000733 |
# |    n_updates        | 31910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 348      |
# |    time_elapsed     | 388      |
# |    total_timesteps  | 135317   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00294  |
# |    n_updates        | 32579    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 348      |
# |    time_elapsed     | 396      |
# |    total_timesteps  | 137861   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.52     |
# |    n_updates        | 33215    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 347      |
# |    time_elapsed     | 407      |
# |    total_timesteps  | 141548   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.2      |
# |    n_updates        | 34136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 347      |
# |    time_elapsed     | 415      |
# |    total_timesteps  | 144240   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.131    |
# |    n_updates        | 34809    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 346      |
# |    time_elapsed     | 424      |
# |    total_timesteps  | 147211   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0159   |
# |    n_updates        | 35552    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 346      |
# |    time_elapsed     | 431      |
# |    total_timesteps  | 149488   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.908    |
# |    n_updates        | 36121    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 345      |
# |    time_elapsed     | 440      |
# |    total_timesteps  | 152420   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.54     |
# |    n_updates        | 36854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 345      |
# |    time_elapsed     | 447      |
# |    total_timesteps  | 154568   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.128    |
# |    n_updates        | 37391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 345      |
# |    time_elapsed     | 453      |
# |    total_timesteps  | 156668   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0165   |
# |    n_updates        | 37916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 345      |
# |    time_elapsed     | 462      |
# |    total_timesteps  | 159618   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00359  |
# |    n_updates        | 38654    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 344      |
# |    time_elapsed     | 470      |
# |    total_timesteps  | 162290   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00188  |
# |    n_updates        | 39322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 344      |
# |    time_elapsed     | 479      |
# |    total_timesteps  | 165096   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.231    |
# |    n_updates        | 40023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 344      |
# |    time_elapsed     | 487      |
# |    total_timesteps  | 167904   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00138  |
# |    n_updates        | 40725    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 344      |
# |    time_elapsed     | 497      |
# |    total_timesteps  | 171003   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.28     |
# |    n_updates        | 41500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 343      |
# |    time_elapsed     | 503      |
# |    total_timesteps  | 173125   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.21     |
# |    n_updates        | 42031    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 343      |
# |    time_elapsed     | 511      |
# |    total_timesteps  | 175726   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00208  |
# |    n_updates        | 42681    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 343      |
# |    time_elapsed     | 521      |
# |    total_timesteps  | 179066   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00198  |
# |    n_updates        | 43516    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 343      |
# |    time_elapsed     | 530      |
# |    total_timesteps  | 181932   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00284  |
# |    n_updates        | 44232    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 342      |
# |    time_elapsed     | 540      |
# |    total_timesteps  | 185370   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000369 |
# |    n_updates        | 45092    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 342      |
# |    time_elapsed     | 552      |
# |    total_timesteps  | 189220   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.84     |
# |    n_updates        | 46054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 342      |
# |    time_elapsed     | 563      |
# |    total_timesteps  | 192740   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.238    |
# |    n_updates        | 46934    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 342      |
# |    time_elapsed     | 572      |
# |    total_timesteps  | 196010   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.22     |
# |    n_updates        | 47752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 341      |
# |    time_elapsed     | 583      |
# |    total_timesteps  | 199413   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00415  |
# |    n_updates        | 48603    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 341      |
# |    time_elapsed     | 590      |
# |    total_timesteps  | 201831   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00861  |
# |    n_updates        | 49207    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 341      |
# |    time_elapsed     | 597      |
# |    total_timesteps  | 204010   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.84     |
# |    n_updates        | 49752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 341      |
# |    time_elapsed     | 605      |
# |    total_timesteps  | 206769   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.002    |
# |    n_updates        | 50442    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 341      |
# |    time_elapsed     | 614      |
# |    total_timesteps  | 209623   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.592    |
# |    n_updates        | 51155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 341      |
# |    time_elapsed     | 620      |
# |    total_timesteps  | 211783   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00452  |
# |    n_updates        | 51695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 340      |
# |    time_elapsed     | 631      |
# |    total_timesteps  | 215404   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00266  |
# |    n_updates        | 52600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 340      |
# |    time_elapsed     | 639      |
# |    total_timesteps  | 218070   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.594    |
# |    n_updates        | 53267    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 340      |
# |    time_elapsed     | 647      |
# |    total_timesteps  | 220664   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00802  |
# |    n_updates        | 53915    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 340      |
# |    time_elapsed     | 655      |
# |    total_timesteps  | 223089   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.886    |
# |    n_updates        | 54522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 340      |
# |    time_elapsed     | 664      |
# |    total_timesteps  | 225965   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000677 |
# |    n_updates        | 55241    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 340      |
# |    time_elapsed     | 672      |
# |    total_timesteps  | 228657   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.878    |
# |    n_updates        | 55914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 340      |
# |    time_elapsed     | 677      |
# |    total_timesteps  | 230344   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0246   |
# |    n_updates        | 56335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 339      |
# |    time_elapsed     | 684      |
# |    total_timesteps  | 232745   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.908    |
# |    n_updates        | 56936    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 339      |
# |    time_elapsed     | 693      |
# |    total_timesteps  | 235772   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.12     |
# |    n_updates        | 57692    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 339      |
# |    time_elapsed     | 703      |
# |    total_timesteps  | 238894   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.228    |
# |    n_updates        | 58473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 339      |
# |    time_elapsed     | 711      |
# |    total_timesteps  | 241666   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00114  |
# |    n_updates        | 59166    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 339      |
# |    time_elapsed     | 721      |
# |    total_timesteps  | 245042   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00339  |
# |    n_updates        | 60010    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 339      |
# |    time_elapsed     | 731      |
# |    total_timesteps  | 248299   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00426  |
# |    n_updates        | 60824    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 339      |
# |    time_elapsed     | 739      |
# |    total_timesteps  | 250758   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000921 |
# |    n_updates        | 61439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 339      |
# |    time_elapsed     | 746      |
# |    total_timesteps  | 253104   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00107  |
# |    n_updates        | 62025    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 338      |
# |    time_elapsed     | 756      |
# |    total_timesteps  | 256460   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.53     |
# |    n_updates        | 62864    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 338      |
# |    time_elapsed     | 763      |
# |    total_timesteps  | 258653   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00222  |
# |    n_updates        | 63413    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 338      |
# |    time_elapsed     | 771      |
# |    total_timesteps  | 261302   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00102  |
# |    n_updates        | 64075    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 338      |
# |    time_elapsed     | 780      |
# |    total_timesteps  | 264324   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00553  |
# |    n_updates        | 64830    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 338      |
# |    time_elapsed     | 791      |
# |    total_timesteps  | 267834   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00636  |
# |    n_updates        | 65708    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 338      |
# |    time_elapsed     | 798      |
# |    total_timesteps  | 270321   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00919  |
# |    n_updates        | 66330    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 338      |
# |    time_elapsed     | 807      |
# |    total_timesteps  | 273320   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.84     |
# |    n_updates        | 67079    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 338      |
# |    time_elapsed     | 816      |
# |    total_timesteps  | 276077   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00976  |
# |    n_updates        | 67769    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 338      |
# |    time_elapsed     | 823      |
# |    total_timesteps  | 278440   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00602  |
# |    n_updates        | 68359    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 337      |
# |    time_elapsed     | 833      |
# |    total_timesteps  | 281640   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.24     |
# |    n_updates        | 69159    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 337      |
# |    time_elapsed     | 841      |
# |    total_timesteps  | 284118   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00204  |
# |    n_updates        | 69779    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 337      |
# |    time_elapsed     | 846      |
# |    total_timesteps  | 285988   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00314  |
# |    n_updates        | 70246    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 337      |
# |    time_elapsed     | 857      |
# |    total_timesteps  | 289662   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0132   |
# |    n_updates        | 71165    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 337      |
# |    time_elapsed     | 867      |
# |    total_timesteps  | 292977   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.287    |
# |    n_updates        | 71994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 337      |
# |    time_elapsed     | 875      |
# |    total_timesteps  | 295548   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0011   |
# |    n_updates        | 72636    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 337      |
# |    time_elapsed     | 883      |
# |    total_timesteps  | 298167   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00364  |
# |    n_updates        | 73291    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training Complete
# Mean Reward: 440.50 +/- 143.88
# Total Episodes: 446
# Model saved to: /kaggle/working/train-mlp-policy-4.zip
# Results saved to: /kaggle/working/train-mlp-policy-4-results.json

# %%
from IPython.display import FileLink
FileLink('train-mlp-policy-4.zip')
# Out:
# /kaggle/working/train-mlp-policy-4.zip
