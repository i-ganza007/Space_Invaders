# %%
import subprocess
import sys

print("Installing dependencies for Kaggle environment...")

# Uninstall conflicting packages first
print("Removing conflicting packages...")
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "-q", "keras", "tensorflow"], 
               stderr=subprocess.DEVNULL)

# Install compatible versions
dependencies = [
    "numpy<2.0",
    "scipy<1.14",
    "protobuf<4.0",
    "tensorboard==2.15.0",
    "stable-baselines3[extra]==2.3.2",
    "ale-py==0.8.1",
    "gymnasium[atari,accept-rom-license]==0.29.1",
    "shimmy[atari]",
]

for dep in dependencies:
    print(f"Installing {dep}...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", dep])

print("\nAll dependencies installed successfully")
print("\nVerifying installation...")
try:
    import ale_py
    import gymnasium as gym
    from stable_baselines3 import DQN
    print("All imports successful!")
except Exception as e:
    print(f"Import error: {e}")
# Out:
# Installing dependencies for Kaggle environment...
# Removing conflicting packages...
# Installing numpy<2.0...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 78.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 1.1.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing scipy<1.14...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 48.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 1.1.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing protobuf<4.0...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 5.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# a2a-sdk 0.3.10 requires protobuf>=5.29.5, but you have protobuf 3.20.3 which is incompatible.
# ray 2.51.1 requires click!=8.3.0,>=7.0, but you have click 8.3.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# tensorflow-metadata 1.17.2 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 46.0.3 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.3.0 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# Installing tensorboard==2.15.0...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 53.8 MB/s eta 0:00:00
# Installing stable-baselines3[extra]==2.3.2...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 4.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing ale-py==0.8.1...
# Installing gymnasium[atari,accept-rom-license]==0.29.1...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 15.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# kaggle-environments 1.18.0 requires gymnasium==0.29.0, but you have gymnasium 0.29.1 which is incompatible.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 0.2.1 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Installing shimmy[atari]...
#
# All dependencies installed successfully
#
# Verifying installation...
# All imports successful!

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import warnings
warnings.filterwarnings('ignore')

import ale_py
import gymnasium as gym
gym.register_envs(ale_py)
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np
import json
import torch
import gc

class LoggingCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(LoggingCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.current_reward = 0
        self.current_length = 0
        
    def _on_step(self):
        self.current_reward += self.locals['rewards'][0]
        self.current_length += 1
        
        if self.locals['dones'][0]:
            self.episode_rewards.append(self.current_reward)
            self.episode_lengths.append(self.current_length)
            self.current_reward = 0
            self.current_length = 0
            
            if len(self.episode_rewards) % 10 == 0:
                gc.collect()
                torch.cuda.empty_cache()
        return True

CONFIG = {
    "lr": 0.00005,
    "gamma": 0.98,
    "batch_size": 128,
    "eps_start": 1.0,
    "eps_end": 0.02,
    "eps_decay": 0.6,
    "policy": "CnnPolicy"
}

print(f"Training Configuration 4:")
print(f"Learning Rate: {CONFIG['lr']}")
print(f"Gamma: {CONFIG['gamma']}")
print(f"Batch Size: {CONFIG['batch_size']}")
print(f"Epsilon: {CONFIG['eps_start']} -> {CONFIG['eps_end']} (decay: {CONFIG['eps_decay']})")

gc.collect()
torch.cuda.empty_cache()

env = gym.make("ALE/SpaceInvaders-v5", frameskip=4)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, n_stack=4)

model = DQN(
    CONFIG["policy"],
    env,
    learning_rate=CONFIG["lr"],
    gamma=CONFIG["gamma"],
    batch_size=CONFIG["batch_size"],
    buffer_size=20000,
    learning_starts=5000,
    exploration_initial_eps=CONFIG["eps_start"],
    exploration_final_eps=CONFIG["eps_end"],
    exploration_fraction=CONFIG["eps_decay"],
    target_update_interval=500,
    train_freq=4,
    gradient_steps=1,
    tensorboard_log="./logs/cnn-policy-4/",
    verbose=1,
    device="cuda" if torch.cuda.is_available() else "cpu"
)

callback = LoggingCallback()

model.learn(
    total_timesteps=300000,
    tb_log_name="SpaceInvaders_CnnPolicy_4",
    callback=callback,
    progress_bar=True
)

mean_reward, std_reward = evaluate_policy(
    model,
    env,
    n_eval_episodes=10,
    deterministic=True
)

results = {
    "config": CONFIG,
    "mean_reward": float(mean_reward),
    "std_reward": float(std_reward),
    "episode_rewards": [float(r) for r in callback.episode_rewards],
    "episode_lengths": [int(l) for l in callback.episode_lengths],
    "total_episodes": len(callback.episode_rewards)
}

model.save("/kaggle/working/train-cnn-policy-4")

with open("/kaggle/working/train-cnn-policy-4-results.json", "w") as f:
    json.dump(results, f, indent=2)

print(f"\nTraining Complete")
print(f"Mean Reward: {mean_reward:.2f} +/- {std_reward:.2f}")
print(f"Total Episodes: {len(callback.episode_rewards)}")
print(f"Model saved to: /kaggle/working/train-cnn-policy-4.zip")
print(f"Results saved to: /kaggle/working/train-cnn-policy-4-results.json")

env.close()
gc.collect()
torch.cuda.empty_cache()
# Out:
# Training Configuration 4:
# Learning Rate: 5e-05
# Gamma: 0.98
# Batch Size: 128
# Epsilon: 1.0 -> 0.02 (decay: 0.6)
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/cnn-policy-4/SpaceInvaders_CnnPolicy_4_1
# Output()
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 364      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1550     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 366      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 3322     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 222      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 5371     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.496    |
# |    n_updates        | 92       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 116      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 6921     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.456    |
# |    n_updates        | 480      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 85       |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 8833     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.3      |
# |    n_updates        | 958      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 71       |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 11054    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.198    |
# |    n_updates        | 1513     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 65       |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 13031    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.369    |
# |    n_updates        | 2007     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 59       |
# |    time_elapsed     | 260      |
# |    total_timesteps  | 15601    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.514    |
# |    n_updates        | 2650     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 57       |
# |    time_elapsed     | 300      |
# |    total_timesteps  | 17334    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.151    |
# |    n_updates        | 3083     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 55       |
# |    time_elapsed     | 353      |
# |    total_timesteps  | 19535    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0106   |
# |    n_updates        | 3633     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 53       |
# |    time_elapsed     | 398      |
# |    total_timesteps  | 21464    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.152    |
# |    n_updates        | 4115     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 50       |
# |    time_elapsed     | 558      |
# |    total_timesteps  | 28338    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0177   |
# |    n_updates        | 5834     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 50       |
# |    time_elapsed     | 603      |
# |    total_timesteps  | 30277    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.206    |
# |    n_updates        | 6319     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 49       |
# |    time_elapsed     | 657      |
# |    total_timesteps  | 32583    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.202    |
# |    n_updates        | 6895     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 48       |
# |    time_elapsed     | 721      |
# |    total_timesteps  | 35281    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.05     |
# |    n_updates        | 7570     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.707    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 46       |
# |    time_elapsed     | 1162     |
# |    total_timesteps  | 53860    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0737   |
# |    n_updates        | 12214    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.695    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 46       |
# |    time_elapsed     | 1213     |
# |    total_timesteps  | 55966    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0169   |
# |    n_updates        | 12741    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.682    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 45       |
# |    time_elapsed     | 1272     |
# |    total_timesteps  | 58419    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.503    |
# |    n_updates        | 13354    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.67     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 45       |
# |    time_elapsed     | 1326     |
# |    total_timesteps  | 60622    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.442    |
# |    n_updates        | 13905    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.648    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 45       |
# |    time_elapsed     | 1424     |
# |    total_timesteps  | 64645    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.38     |
# |    n_updates        | 14911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.637    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 45       |
# |    time_elapsed     | 1476     |
# |    total_timesteps  | 66754    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.407    |
# |    n_updates        | 15438    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.626    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 45       |
# |    time_elapsed     | 1525     |
# |    total_timesteps  | 68736    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.547    |
# |    n_updates        | 15933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.613    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 44       |
# |    time_elapsed     | 1583     |
# |    total_timesteps  | 71103    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.215    |
# |    n_updates        | 16525    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.599    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 44       |
# |    time_elapsed     | 1647     |
# |    total_timesteps  | 73662    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.616    |
# |    n_updates        | 17165    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.584    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 44       |
# |    time_elapsed     | 1715     |
# |    total_timesteps  | 76393    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.628    |
# |    n_updates        | 17848    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.566    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 44       |
# |    time_elapsed     | 1796     |
# |    total_timesteps  | 79654    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.498    |
# |    n_updates        | 18663    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.552    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 44       |
# |    time_elapsed     | 1861     |
# |    total_timesteps  | 82238    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.358    |
# |    n_updates        | 19309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.54     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 44       |
# |    time_elapsed     | 1917     |
# |    total_timesteps  | 84486    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.105    |
# |    n_updates        | 19871    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 43       |
# |    time_elapsed     | 1984     |
# |    total_timesteps  | 87146    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.447    |
# |    n_updates        | 20536    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.512    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 43       |
# |    time_elapsed     | 2049     |
# |    total_timesteps  | 89723    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.18     |
# |    n_updates        | 21180    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.499    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 43       |
# |    time_elapsed     | 2108     |
# |    total_timesteps  | 92094    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.243    |
# |    n_updates        | 21773    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.487    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 43       |
# |    time_elapsed     | 2164     |
# |    total_timesteps  | 94283    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.22     |
# |    n_updates        | 22320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.473    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 43       |
# |    time_elapsed     | 2226     |
# |    total_timesteps  | 96738    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.298    |
# |    n_updates        | 22934    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.459    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 43       |
# |    time_elapsed     | 2291     |
# |    total_timesteps  | 99311    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.2      |
# |    n_updates        | 23577    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.449    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 43       |
# |    time_elapsed     | 2341     |
# |    total_timesteps  | 101258   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.369    |
# |    n_updates        | 24064    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 43       |
# |    time_elapsed     | 2408     |
# |    total_timesteps  | 103922   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.449    |
# |    n_updates        | 24730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.419    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 43       |
# |    time_elapsed     | 2481     |
# |    total_timesteps  | 106798   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.536    |
# |    n_updates        | 25449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.406    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 42       |
# |    time_elapsed     | 2540     |
# |    total_timesteps  | 109090   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.423    |
# |    n_updates        | 26022    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.393    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 42       |
# |    time_elapsed     | 2600     |
# |    total_timesteps  | 111409   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.334    |
# |    n_updates        | 26602    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.381    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 42       |
# |    time_elapsed     | 2659     |
# |    total_timesteps  | 113729   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.443    |
# |    n_updates        | 27182    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.373    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 42       |
# |    time_elapsed     | 2697     |
# |    total_timesteps  | 115183   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.401    |
# |    n_updates        | 27545    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.358    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 42       |
# |    time_elapsed     | 2767     |
# |    total_timesteps  | 117925   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.965    |
# |    n_updates        | 28231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.345    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 42       |
# |    time_elapsed     | 2827     |
# |    total_timesteps  | 120244   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0996   |
# |    n_updates        | 28810    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.335    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 42       |
# |    time_elapsed     | 2874     |
# |    total_timesteps  | 122065   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.709    |
# |    n_updates        | 29266    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.323    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 42       |
# |    time_elapsed     | 2935     |
# |    total_timesteps  | 124428   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.547    |
# |    n_updates        | 29856    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.309    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 42       |
# |    time_elapsed     | 3000     |
# |    total_timesteps  | 126955   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.166    |
# |    n_updates        | 30488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.294    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 42       |
# |    time_elapsed     | 3072     |
# |    total_timesteps  | 129757   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.196    |
# |    n_updates        | 31189    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.276    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 42       |
# |    time_elapsed     | 3153     |
# |    total_timesteps  | 132898   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.88     |
# |    n_updates        | 31974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.261    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 42       |
# |    time_elapsed     | 3227     |
# |    total_timesteps  | 135749   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.633    |
# |    n_updates        | 32687    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.247    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 41       |
# |    time_elapsed     | 3293     |
# |    total_timesteps  | 138297   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.337    |
# |    n_updates        | 33324    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.235    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 41       |
# |    time_elapsed     | 3352     |
# |    total_timesteps  | 140598   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.437    |
# |    n_updates        | 33899    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.218    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 41       |
# |    time_elapsed     | 3430     |
# |    total_timesteps  | 143587   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.718    |
# |    n_updates        | 34646    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.206    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 41       |
# |    time_elapsed     | 3489     |
# |    total_timesteps  | 145865   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.417    |
# |    n_updates        | 35216    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.19     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 41       |
# |    time_elapsed     | 3563     |
# |    total_timesteps  | 148736   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.57     |
# |    n_updates        | 35933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.177    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 41       |
# |    time_elapsed     | 3626     |
# |    total_timesteps  | 151164   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.499    |
# |    n_updates        | 36540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.163    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 41       |
# |    time_elapsed     | 3692     |
# |    total_timesteps  | 153686   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.646    |
# |    n_updates        | 37171    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.152    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 41       |
# |    time_elapsed     | 3746     |
# |    total_timesteps  | 155789   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.482    |
# |    n_updates        | 37697    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.139    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 41       |
# |    time_elapsed     | 3810     |
# |    total_timesteps  | 158225   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.302    |
# |    n_updates        | 38306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.124    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 41       |
# |    time_elapsed     | 3879     |
# |    total_timesteps  | 160872   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.424    |
# |    n_updates        | 38967    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.111    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 41       |
# |    time_elapsed     | 3942     |
# |    total_timesteps  | 163305   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.647    |
# |    n_updates        | 39576    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0967   |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 41       |
# |    time_elapsed     | 4011     |
# |    total_timesteps  | 165920   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.163    |
# |    n_updates        | 40229    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0834   |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 41       |
# |    time_elapsed     | 4074     |
# |    total_timesteps  | 168349   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.326    |
# |    n_updates        | 40837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0665   |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 41       |
# |    time_elapsed     | 4155     |
# |    total_timesteps  | 171460   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.75     |
# |    n_updates        | 41614    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0538   |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 41       |
# |    time_elapsed     | 4216     |
# |    total_timesteps  | 173789   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.807    |
# |    n_updates        | 42197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0437   |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 41       |
# |    time_elapsed     | 4265     |
# |    total_timesteps  | 175646   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.348    |
# |    n_updates        | 42661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0319   |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 41       |
# |    time_elapsed     | 4322     |
# |    total_timesteps  | 177814   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.16     |
# |    n_updates        | 43203    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 41       |
# |    time_elapsed     | 4386     |
# |    total_timesteps  | 180240   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.384    |
# |    n_updates        | 43809    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 41       |
# |    time_elapsed     | 4455     |
# |    total_timesteps  | 182857   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.85     |
# |    n_updates        | 44464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 40       |
# |    time_elapsed     | 4518     |
# |    total_timesteps  | 185239   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.409    |
# |    n_updates        | 45059    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 40       |
# |    time_elapsed     | 4577     |
# |    total_timesteps  | 187511   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.869    |
# |    n_updates        | 45627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 40       |
# |    time_elapsed     | 4651     |
# |    total_timesteps  | 190334   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.615    |
# |    n_updates        | 46333    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 40       |
# |    time_elapsed     | 4713     |
# |    total_timesteps  | 192683   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.555    |
# |    n_updates        | 46920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 40       |
# |    time_elapsed     | 4771     |
# |    total_timesteps  | 194888   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.567    |
# |    n_updates        | 47471    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 40       |
# |    time_elapsed     | 4853     |
# |    total_timesteps  | 198019   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.411    |
# |    n_updates        | 48254    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 40       |
# |    time_elapsed     | 4911     |
# |    total_timesteps  | 200242   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.438    |
# |    n_updates        | 48810    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 40       |
# |    time_elapsed     | 4985     |
# |    total_timesteps  | 203053   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.532    |
# |    n_updates        | 49513    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 40       |
# |    time_elapsed     | 5040     |
# |    total_timesteps  | 205136   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.594    |
# |    n_updates        | 50033    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 40       |
# |    time_elapsed     | 5095     |
# |    total_timesteps  | 207242   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.905    |
# |    n_updates        | 50560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 40       |
# |    time_elapsed     | 5166     |
# |    total_timesteps  | 209951   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.457    |
# |    n_updates        | 51237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 40       |
# |    time_elapsed     | 5240     |
# |    total_timesteps  | 212741   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.669    |
# |    n_updates        | 51935    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 40       |
# |    time_elapsed     | 5296     |
# |    total_timesteps  | 214877   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.76     |
# |    n_updates        | 52469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 40       |
# |    time_elapsed     | 5345     |
# |    total_timesteps  | 216761   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.556    |
# |    n_updates        | 52940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 40       |
# |    time_elapsed     | 5400     |
# |    total_timesteps  | 218851   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.714    |
# |    n_updates        | 53462    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 40       |
# |    time_elapsed     | 5472     |
# |    total_timesteps  | 221611   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.21     |
# |    n_updates        | 54152    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 40       |
# |    time_elapsed     | 5529     |
# |    total_timesteps  | 223775   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.596    |
# |    n_updates        | 54693    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 40       |
# |    time_elapsed     | 5590     |
# |    total_timesteps  | 226097   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.588    |
# |    n_updates        | 55274    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 40       |
# |    time_elapsed     | 5658     |
# |    total_timesteps  | 228676   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.484    |
# |    n_updates        | 55918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 40       |
# |    time_elapsed     | 5715     |
# |    total_timesteps  | 230850   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.693    |
# |    n_updates        | 56462    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 39       |
# |    time_elapsed     | 6878     |
# |    total_timesteps  | 275044   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.464    |
# |    n_updates        | 67510    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 39       |
# |    time_elapsed     | 6964     |
# |    total_timesteps  | 278324   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.98     |
# |    n_updates        | 68330    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 39       |
# |    time_elapsed     | 7039     |
# |    total_timesteps  | 281191   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.352    |
# |    n_updates        | 69047    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 39       |
# |    time_elapsed     | 7173     |
# |    total_timesteps  | 286289   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.865    |
# |    n_updates        | 70322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 39       |
# |    time_elapsed     | 7241     |
# |    total_timesteps  | 288862   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.55     |
# |    n_updates        | 70965    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 39       |
# |    time_elapsed     | 7306     |
# |    total_timesteps  | 291341   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.512    |
# |    n_updates        | 71585    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 39       |
# |    time_elapsed     | 7380     |
# |    total_timesteps  | 294200   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.596    |
# |    n_updates        | 72299    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 39       |
# |    time_elapsed     | 7469     |
# |    total_timesteps  | 297587   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.253    |
# |    n_updates        | 73146    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 39       |
# |    time_elapsed     | 7524     |
# |    total_timesteps  | 299671   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.31     |
# |    n_updates        | 73667    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training Complete
# Mean Reward: 354.00 +/- 136.12
# Total Episodes: 496
# Model saved to: /kaggle/working/train-cnn-policy-4.zip
# Results saved to: /kaggle/working/train-cnn-policy-4-results.json

# %%
from IPython.display import FileLink
FileLink('train-cnn-policy-3.zip')
# Out:
# /kaggle/working/train-cnn-policy-3.zip
