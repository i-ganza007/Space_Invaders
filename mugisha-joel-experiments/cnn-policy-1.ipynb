# %%
import subprocess
import sys

print("Installing dependencies for Kaggle environment...")

# Uninstall conflicting packages first
print("Removing conflicting packages...")
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "-q", "keras", "tensorflow"], 
               stderr=subprocess.DEVNULL)

# Install compatible versions
dependencies = [
    "numpy<2.0",
    "scipy<1.14",
    "protobuf<4.0",
    "tensorboard==2.15.0",
    "stable-baselines3[extra]==2.3.2",
    "ale-py==0.8.1",
    "gymnasium[atari,accept-rom-license]==0.29.1",
    "shimmy[atari]",
]

for dep in dependencies:
    print(f"Installing {dep}...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", dep])

print("\nAll dependencies installed successfully")
print("\nVerifying installation...")
try:
    import ale_py
    import gymnasium as gym
    from stable_baselines3 import DQN
    print("All imports successful!")
except Exception as e:
    print(f"Import error: {e}")
# Out:
# Installing dependencies for Kaggle environment...
# Removing conflicting packages...
# Installing numpy<2.0...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 78.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 1.1.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing scipy<1.14...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 48.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 1.1.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing protobuf<4.0...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 5.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# a2a-sdk 0.3.10 requires protobuf>=5.29.5, but you have protobuf 3.20.3 which is incompatible.
# ray 2.51.1 requires click!=8.3.0,>=7.0, but you have click 8.3.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# tensorflow-metadata 1.17.2 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 46.0.3 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.3.0 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# Installing tensorboard==2.15.0...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 53.8 MB/s eta 0:00:00
# Installing stable-baselines3[extra]==2.3.2...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 4.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Installing ale-py==0.8.1...
# Installing gymnasium[atari,accept-rom-license]==0.29.1...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 15.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# kaggle-environments 1.18.0 requires gymnasium==0.29.0, but you have gymnasium 0.29.1 which is incompatible.
# kaggle-environments 1.18.0 requires shimmy>=1.2.1, but you have shimmy 0.2.1 which is incompatible.
# kaggle-environments 1.18.0 requires stable-baselines3==2.1.0, but you have stable-baselines3 2.3.2 which is incompatible.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Installing shimmy[atari]...
#
# All dependencies installed successfully
#
# Verifying installation...
# All imports successful!

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import warnings
warnings.filterwarnings('ignore')

import ale_py
import gymnasium as gym
gym.register_envs(ale_py)
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np
import json
import torch
import gc

class LoggingCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(LoggingCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.episode_lengths = []
        self.current_reward = 0
        self.current_length = 0
        
    def _on_step(self):
        self.current_reward += self.locals['rewards'][0]
        self.current_length += 1
        
        if self.locals['dones'][0]:
            self.episode_rewards.append(self.current_reward)
            self.episode_lengths.append(self.current_length)
            self.current_reward = 0
            self.current_length = 0
            
            if len(self.episode_rewards) % 10 == 0:
                gc.collect()
                torch.cuda.empty_cache()
        return True

CONFIG = {
    "lr": 0.0001,
    "gamma": 0.99,
    "batch_size": 16,
    "eps_start": 1.0,
    "eps_end": 0.05,
    "eps_decay": 0.3,
    "policy": "CnnPolicy"
}

print(f"Training Configuration 1:")
print(f"Learning Rate: {CONFIG['lr']}")
print(f"Gamma: {CONFIG['gamma']}")
print(f"Batch Size: {CONFIG['batch_size']}")
print(f"Epsilon: {CONFIG['eps_start']} -> {CONFIG['eps_end']} (decay: {CONFIG['eps_decay']})")

gc.collect()
torch.cuda.empty_cache()

env = gym.make("ALE/SpaceInvaders-v5", frameskip=4)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, n_stack=4)

model = DQN(
    CONFIG["policy"],
    env,
    learning_rate=CONFIG["lr"],
    gamma=CONFIG["gamma"],
    batch_size=CONFIG["batch_size"],
    buffer_size=20000,
    learning_starts=5000,
    exploration_initial_eps=CONFIG["eps_start"],
    exploration_final_eps=CONFIG["eps_end"],
    exploration_fraction=CONFIG["eps_decay"],
    target_update_interval=500,
    train_freq=4,
    gradient_steps=1,
    tensorboard_log="./logs/cnn-policy-1/",
    verbose=1,
    device="cuda" if torch.cuda.is_available() else "cpu"
)

callback = LoggingCallback()

model.learn(
    total_timesteps=300000,
    tb_log_name="SpaceInvaders_CnnPolicy_1",
    callback=callback,
    progress_bar=True
)

mean_reward, std_reward = evaluate_policy(
    model,
    env,
    n_eval_episodes=10,
    deterministic=True
)

results = {
    "config": CONFIG,
    "mean_reward": float(mean_reward),
    "std_reward": float(std_reward),
    "episode_rewards": [float(r) for r in callback.episode_rewards],
    "episode_lengths": [int(l) for l in callback.episode_lengths],
    "total_episodes": len(callback.episode_rewards)
}

model.save("/kaggle/working/train-cnn-policy-1")

with open("/kaggle/working/train-cnn-policy-1-results.json", "w") as f:
    json.dump(results, f, indent=2)

print(f"\nTraining Complete")
print(f"Mean Reward: {mean_reward:.2f} +/- {std_reward:.2f}")
print(f"Total Episodes: {len(callback.episode_rewards)}")
print(f"Model saved to: /kaggle/working/train-cnn-policy-1.zip")
print(f"Results saved to: /kaggle/working/train-cnn-policy-1-results.json")

env.close()
gc.collect()
torch.cuda.empty_cache()
# Out:
# Training Configuration 1:
# Learning Rate: 0.0001
# Gamma: 0.99
# Batch Size: 16
# Epsilon: 1.0 -> 0.05 (decay: 0.3)
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/cnn-policy-1/SpaceInvaders_CnnPolicy_1_1
# Output()
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 353      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2068     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 359      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 3816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 262      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 6175     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.28     |
# |    n_updates        | 293      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 216      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 8097     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00145  |
# |    n_updates        | 774      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 188      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 10492    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.18     |
# |    n_updates        | 1372     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 176      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 12576    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00107  |
# |    n_updates        | 1893     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 167      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 14667    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000514 |
# |    n_updates        | 2416     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.816    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 159      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 17423    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00203  |
# |    n_updates        | 3105     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 154      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 19556    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00235  |
# |    n_updates        | 3638     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.778    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 152      |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 21034    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00615  |
# |    n_updates        | 4008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 151      |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 23780    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0024   |
# |    n_updates        | 4694     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.725    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 150      |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 26039    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.595    |
# |    n_updates        | 5259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.701    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 149      |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 28371    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21     |
# |    n_updates        | 5842     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.677    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 149      |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 30627    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00424  |
# |    n_updates        | 6406     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 148      |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 32355    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.28     |
# |    n_updates        | 6838     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.641    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 147      |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 34007    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00243  |
# |    n_updates        | 7251     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.623    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 147      |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 35723    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00517  |
# |    n_updates        | 7680     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.606    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 146      |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 37350    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00315  |
# |    n_updates        | 8087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.584    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 145      |
# |    time_elapsed     | 270      |
# |    total_timesteps  | 39388    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.86     |
# |    n_updates        | 8596     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.562    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 144      |
# |    time_elapsed     | 286      |
# |    total_timesteps  | 41463    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00919  |
# |    n_updates        | 9115     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.542    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 144      |
# |    time_elapsed     | 301      |
# |    total_timesteps  | 43410    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 9602     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.518    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 143      |
# |    time_elapsed     | 317      |
# |    total_timesteps  | 45641    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0294   |
# |    n_updates        | 10160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.497    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 142      |
# |    time_elapsed     | 333      |
# |    total_timesteps  | 47665    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0257   |
# |    n_updates        | 10666    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.471    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 142      |
# |    time_elapsed     | 352      |
# |    total_timesteps  | 50092    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 11272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.447    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 141      |
# |    time_elapsed     | 370      |
# |    total_timesteps  | 52345    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.83     |
# |    n_updates        | 11836    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.426    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 140      |
# |    time_elapsed     | 386      |
# |    total_timesteps  | 54381    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0433   |
# |    n_updates        | 12345    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.401    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 140      |
# |    time_elapsed     | 405      |
# |    total_timesteps  | 56781    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0367   |
# |    n_updates        | 12945    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.373    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 139      |
# |    time_elapsed     | 426      |
# |    total_timesteps  | 59367    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0815   |
# |    n_updates        | 13591    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.352    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 138      |
# |    time_elapsed     | 443      |
# |    total_timesteps  | 61417    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.123    |
# |    n_updates        | 14104    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.324    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 137      |
# |    time_elapsed     | 465      |
# |    total_timesteps  | 64074    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.105    |
# |    n_updates        | 14768    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.298    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 137      |
# |    time_elapsed     | 485      |
# |    total_timesteps  | 66528    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.221    |
# |    n_updates        | 15381    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.272    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 136      |
# |    time_elapsed     | 506      |
# |    total_timesteps  | 68971    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0997   |
# |    n_updates        | 15992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.244    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 135      |
# |    time_elapsed     | 529      |
# |    total_timesteps  | 71654    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0509   |
# |    n_updates        | 16663    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.216    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 134      |
# |    time_elapsed     | 551      |
# |    total_timesteps  | 74246    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.111    |
# |    n_updates        | 17311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.197    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 134      |
# |    time_elapsed     | 567      |
# |    total_timesteps  | 76106    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.343    |
# |    n_updates        | 17776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.177    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 133      |
# |    time_elapsed     | 583      |
# |    total_timesteps  | 77961    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.4      |
# |    n_updates        | 18240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.151    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 132      |
# |    time_elapsed     | 605      |
# |    total_timesteps  | 80419    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.61     |
# |    n_updates        | 18854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.122    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 132      |
# |    time_elapsed     | 629      |
# |    total_timesteps  | 83137    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.02     |
# |    n_updates        | 19534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0919   |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 131      |
# |    time_elapsed     | 654      |
# |    total_timesteps  | 86028    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.076    |
# |    n_updates        | 20256    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0691   |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 130      |
# |    time_elapsed     | 674      |
# |    total_timesteps  | 88188    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.131    |
# |    n_updates        | 20796    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 130      |
# |    time_elapsed     | 699      |
# |    total_timesteps  | 90983    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0519   |
# |    n_updates        | 21495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 129      |
# |    time_elapsed     | 725      |
# |    total_timesteps  | 93983    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.117    |
# |    n_updates        | 22245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 129      |
# |    time_elapsed     | 744      |
# |    total_timesteps  | 96134    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0372   |
# |    n_updates        | 22783    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 128      |
# |    time_elapsed     | 766      |
# |    total_timesteps  | 98627    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.88     |
# |    n_updates        | 23406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 128      |
# |    time_elapsed     | 785      |
# |    total_timesteps  | 100664   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0852   |
# |    n_updates        | 23915    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 127      |
# |    time_elapsed     | 806      |
# |    total_timesteps  | 102997   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.11     |
# |    n_updates        | 24499    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 127      |
# |    time_elapsed     | 827      |
# |    total_timesteps  | 105426   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.228    |
# |    n_updates        | 25106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 126      |
# |    time_elapsed     | 845      |
# |    total_timesteps  | 107418   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.392    |
# |    n_updates        | 25604    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 126      |
# |    time_elapsed     | 871      |
# |    total_timesteps  | 110316   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.173    |
# |    n_updates        | 26328    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 126      |
# |    time_elapsed     | 895      |
# |    total_timesteps  | 112978   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.347    |
# |    n_updates        | 26994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 125      |
# |    time_elapsed     | 916      |
# |    total_timesteps  | 115252   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.17     |
# |    n_updates        | 27562    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 125      |
# |    time_elapsed     | 940      |
# |    total_timesteps  | 117916   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.61     |
# |    n_updates        | 28228    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 125      |
# |    time_elapsed     | 961      |
# |    total_timesteps  | 120269   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.101    |
# |    n_updates        | 28817    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 124      |
# |    time_elapsed     | 987      |
# |    total_timesteps  | 123216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.228    |
# |    n_updates        | 29553    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 124      |
# |    time_elapsed     | 1012     |
# |    total_timesteps  | 125993   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.41     |
# |    n_updates        | 30248    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 124      |
# |    time_elapsed     | 1039     |
# |    total_timesteps  | 128946   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.455    |
# |    n_updates        | 30986    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 123      |
# |    time_elapsed     | 1065     |
# |    total_timesteps  | 131879   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.163    |
# |    n_updates        | 31719    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 123      |
# |    time_elapsed     | 1082     |
# |    total_timesteps  | 133743   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.119    |
# |    n_updates        | 32185    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 123      |
# |    time_elapsed     | 1106     |
# |    total_timesteps  | 136449   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.631    |
# |    n_updates        | 32862    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 122      |
# |    time_elapsed     | 1136     |
# |    total_timesteps  | 139790   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.278    |
# |    n_updates        | 33697    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 122      |
# |    time_elapsed     | 1160     |
# |    total_timesteps  | 142527   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.372    |
# |    n_updates        | 34381    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 122      |
# |    time_elapsed     | 1184     |
# |    total_timesteps  | 145189   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.271    |
# |    n_updates        | 35047    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 122      |
# |    time_elapsed     | 1211     |
# |    total_timesteps  | 148126   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0998   |
# |    n_updates        | 35781    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 122      |
# |    time_elapsed     | 1241     |
# |    total_timesteps  | 151579   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.32     |
# |    n_updates        | 36644    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 121      |
# |    time_elapsed     | 1271     |
# |    total_timesteps  | 154903   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0314   |
# |    n_updates        | 37475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 121      |
# |    time_elapsed     | 1295     |
# |    total_timesteps  | 157556   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.579    |
# |    n_updates        | 38138    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 121      |
# |    time_elapsed     | 1315     |
# |    total_timesteps  | 159823   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.84     |
# |    n_updates        | 38705    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 121      |
# |    time_elapsed     | 1338     |
# |    total_timesteps  | 162336   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.698    |
# |    n_updates        | 39333    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 121      |
# |    time_elapsed     | 1370     |
# |    total_timesteps  | 165938   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.16     |
# |    n_updates        | 40234    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 120      |
# |    time_elapsed     | 1395     |
# |    total_timesteps  | 168662   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0848   |
# |    n_updates        | 40915    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 120      |
# |    time_elapsed     | 1416     |
# |    total_timesteps  | 171024   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.489    |
# |    n_updates        | 41505    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 120      |
# |    time_elapsed     | 1440     |
# |    total_timesteps  | 173777   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.315    |
# |    n_updates        | 42194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 120      |
# |    time_elapsed     | 1465     |
# |    total_timesteps  | 176572   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.284    |
# |    n_updates        | 42892    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 120      |
# |    time_elapsed     | 1493     |
# |    total_timesteps  | 179713   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.134    |
# |    n_updates        | 43678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 120      |
# |    time_elapsed     | 1516     |
# |    total_timesteps  | 182246   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.249    |
# |    n_updates        | 44311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 120      |
# |    time_elapsed     | 1537     |
# |    total_timesteps  | 184560   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.168    |
# |    n_updates        | 44889    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 119      |
# |    time_elapsed     | 1558     |
# |    total_timesteps  | 186910   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.16     |
# |    n_updates        | 45477    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 119      |
# |    time_elapsed     | 1587     |
# |    total_timesteps  | 190184   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.583    |
# |    n_updates        | 46295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 119      |
# |    time_elapsed     | 1613     |
# |    total_timesteps  | 193090   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0706   |
# |    n_updates        | 47022    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 119      |
# |    time_elapsed     | 1637     |
# |    total_timesteps  | 195746   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.465    |
# |    n_updates        | 47686    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 119      |
# |    time_elapsed     | 1660     |
# |    total_timesteps  | 198373   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.259    |
# |    n_updates        | 48343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 119      |
# |    time_elapsed     | 1682     |
# |    total_timesteps  | 200792   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.414    |
# |    n_updates        | 48947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 119      |
# |    time_elapsed     | 1708     |
# |    total_timesteps  | 203487   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.188    |
# |    n_updates        | 49621    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 118      |
# |    time_elapsed     | 1734     |
# |    total_timesteps  | 206284   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.03     |
# |    n_updates        | 50320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 118      |
# |    time_elapsed     | 1765     |
# |    total_timesteps  | 209685   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.449    |
# |    n_updates        | 51171    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 118      |
# |    time_elapsed     | 1790     |
# |    total_timesteps  | 212452   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1      |
# |    n_updates        | 51862    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 118      |
# |    time_elapsed     | 1814     |
# |    total_timesteps  | 215004   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.092    |
# |    n_updates        | 52500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 118      |
# |    time_elapsed     | 1840     |
# |    total_timesteps  | 217847   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.481    |
# |    n_updates        | 53211    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 118      |
# |    time_elapsed     | 1861     |
# |    total_timesteps  | 220231   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.229    |
# |    n_updates        | 53807    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 118      |
# |    time_elapsed     | 1886     |
# |    total_timesteps  | 222954   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.198    |
# |    n_updates        | 54488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 118      |
# |    time_elapsed     | 1911     |
# |    total_timesteps  | 225584   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.123    |
# |    n_updates        | 55145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 117      |
# |    time_elapsed     | 1935     |
# |    total_timesteps  | 228213   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.346    |
# |    n_updates        | 55803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 117      |
# |    time_elapsed     | 1962     |
# |    total_timesteps  | 231184   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.118    |
# |    n_updates        | 56545    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 117      |
# |    time_elapsed     | 1987     |
# |    total_timesteps  | 233916   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.28     |
# |    n_updates        | 57228    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 117      |
# |    time_elapsed     | 2018     |
# |    total_timesteps  | 237225   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.353    |
# |    n_updates        | 58056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 117      |
# |    time_elapsed     | 2049     |
# |    total_timesteps  | 240637   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.191    |
# |    n_updates        | 58909    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 117      |
# |    time_elapsed     | 2075     |
# |    total_timesteps  | 243609   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.275    |
# |    n_updates        | 59652    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 117      |
# |    time_elapsed     | 2102     |
# |    total_timesteps  | 246457   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.63     |
# |    n_updates        | 60364    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 117      |
# |    time_elapsed     | 2130     |
# |    total_timesteps  | 249658   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.369    |
# |    n_updates        | 61164    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 117      |
# |    time_elapsed     | 2157     |
# |    total_timesteps  | 252540   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.261    |
# |    n_updates        | 61884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 116      |
# |    time_elapsed     | 2181     |
# |    total_timesteps  | 255260   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.518    |
# |    n_updates        | 62564    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 116      |
# |    time_elapsed     | 2206     |
# |    total_timesteps  | 258079   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.504    |
# |    n_updates        | 63269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 116      |
# |    time_elapsed     | 2232     |
# |    total_timesteps  | 260974   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.295    |
# |    n_updates        | 63993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 116      |
# |    time_elapsed     | 2260     |
# |    total_timesteps  | 264065   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.414    |
# |    n_updates        | 64766    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 116      |
# |    time_elapsed     | 2281     |
# |    total_timesteps  | 266330   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.253    |
# |    n_updates        | 65332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 116      |
# |    time_elapsed     | 2312     |
# |    total_timesteps  | 269599   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.554    |
# |    n_updates        | 66149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 116      |
# |    time_elapsed     | 2333     |
# |    total_timesteps  | 271873   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.355    |
# |    n_updates        | 66718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 116      |
# |    time_elapsed     | 2358     |
# |    total_timesteps  | 274509   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.597    |
# |    n_updates        | 67377    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 116      |
# |    time_elapsed     | 2377     |
# |    total_timesteps  | 276572   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.981    |
# |    n_updates        | 67892    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 116      |
# |    time_elapsed     | 2400     |
# |    total_timesteps  | 279119   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.381    |
# |    n_updates        | 68529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 116      |
# |    time_elapsed     | 2428     |
# |    total_timesteps  | 282074   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.192    |
# |    n_updates        | 69268    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 116      |
# |    time_elapsed     | 2453     |
# |    total_timesteps  | 284907   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.251    |
# |    n_updates        | 69976    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 116      |
# |    time_elapsed     | 2482     |
# |    total_timesteps  | 287985   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.221    |
# |    n_updates        | 70746    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 115      |
# |    time_elapsed     | 2505     |
# |    total_timesteps  | 290441   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.366    |
# |    n_updates        | 71360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 115      |
# |    time_elapsed     | 2532     |
# |    total_timesteps  | 293436   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.888    |
# |    n_updates        | 72108    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 115      |
# |    time_elapsed     | 2565     |
# |    total_timesteps  | 296973   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.733    |
# |    n_updates        | 72993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 115      |
# |    time_elapsed     | 2588     |
# |    total_timesteps  | 299603   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.204    |
# |    n_updates        | 73650    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training Complete
# Mean Reward: 244.50 +/- 51.89
# Total Episodes: 468
# Model saved to: /kaggle/working/train-cnn-policy-1.zip
# Results saved to: /kaggle/working/train-cnn-policy-1-results.json
